# %% [markdown]
# Polychrom Customizing Simulation

# %%
import polychrom
#print(polychrom.__file__)
#check if you have polychrom, if not, please cp to your appropriate directory
#https://github.com/open2c/polychrom.git

# %%
#from polychrom import contactmaps
#print(contactmaps.__file__)
#check the path

# %%
import os
import sys

# %%
import datetime

# %%
#print(os.getcwd()) #check your current cwd

# %%
import openmm #you mush have openmm to run the simulation

import polychrom
from polychrom import forcekits, forces, simulation, starting_conformations
from polychrom.hdf5_format import HDF5Reporter

# %%
def create_polymer(N, polymer_creation_func, method, boxSize=100, r1=10, r2=13, step_size=1.0):

    """
    Polymer Generator
    """
    
    if polymer_creation_func == "grow_cubic":
        polymer = starting_conformations.grow_cubic(N, boxSize, method=method)
            #boxSize : cubic place to grow polymers. size of boxSize**3
            #methods : standard, linear, extended
            #standard : closed chain, ring polymer (ring)
            #linear : open chain, not connected (not a ring)
            #extended : long loop (ring)
            #we do not consider the strand crossing due to Topoisomerase II in this grow_cubic simulation
        return polymer

    elif polymer_creation_func == "create_spiral":
        polymer = starting_conformations.create_spiral(r1, r2, N)
        return polymer

    elif polymer_creation_func == "create_random_walk":
        polymer = starting_conformations.create_random_walk(step_size, N)
        return polymer

    elif polymer_creation_func == "create_constrained_random_walk":
        pass
        #work in progress

    else:
        raise ValueError(f"Unknown polymer_creation_func: {polymer_creation_func}")

# %%
def add_confinement(sim, polymer_force_conf, density, k, r="density"):
    if polymer_force_conf == "spherical_confinement":
        sim.add_force(forces.spherical_confinement(sim, density=density, k=k))
            #forces.spherical_confinement(sim, r="density", density=0.85, k=1)
            #~ k is the spring constant, the steepness of the wall (nucleus)
            #r is the radius, the default is density, you can change it manually (unit of nm)

    elif polymer_force_conf == "cylindrical_confinement":
        sim.add_force(forces.cylindrical_confinement(sim, k=k, top=9999))
    #cylindrical_confinement(sim_object, r, bottom=None, k=0.1, top=9999)

    else:
        raise ValueError(f"Unknown polymer_force_conf: {polymer_force_conf} or maybe working in progress, please try another force")

# %%
def add_polymer_physics(sim, is_ring = False, trunc = 3.0, angle_k = 1.5, bond_length = 1.0, bond_wiggle = 0.05):
    
    sim.add_force(
        forcekits.polymer_chains(
            sim,
            chains=[(0, None, is_ring)],
            #chains=[(start, end, isRing)]
            #ende == None --> from start to the final one (0 to N-1)
            #isRing == False --> linear, not a ring / isRing == True --> ring
            # By default the library assumes you have one polymer chain
            # If you want to make it a ring, or more than one chain, use self.setChains
            # self.setChains([(0,50,True),(50,None,False)]) will set a 50-monomer ring and a chain from 50 to the end
        
            bond_force_func=forces.harmonic_bonds,
            bond_force_kwargs={
                "bondLength": 1.0,
                "bondWiggleDistance": 0.05,  # Bond distance will fluctuate +- 0.05 on average
            },
            angle_force_func=forces.angle_force,
            angle_force_kwargs={
                "k": 1.5,
                # K is more or less arbitrary, k=4 corresponds to presistence length of 4,
                # k=1.5 is recommended to make polymer realistically flexible; k=8 is very stiff
            },
            nonbonded_force_func=forces.polynomial_repulsive,
            nonbonded_force_kwargs={
                "trunc": trunc,  # this will let chains cross sometimes
                # 'trunc':10.0, # this will resolve chain crossings and will not let chain cross anymore
            },
            except_bonds=True, #if False, then neighbour beads connected to the bond would gather and become so compact... (due to non-bonded forces)
            extra_bonds=None, #or you can put list [(i,j)] of extra bonds
            extra_triplets=None,
            override_checks=False
        )
    )

#making the physics of DNA

# %%
def make_simulation(
    N,
    polymer_creation_func,
    method,
    boxSize=100,
    trunc=3.0,
    density=0.85,
    angle_k=1.5,
    is_ring=False,
    k=1.0,
    bond_length=1.0,
    bond_wiggle=0.05,
    polymer_force_conf="spherical_confinement",
    max_data_length = 5
):
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    folder_name = f"trajectory_{timestamp}"
    reporter = HDF5Reporter(folder=folder_name, max_data_length = max_data_length, overwrite=True)

    """
    Basic Parameters for the Simulation
    """
    sim = simulation.Simulation(
        platform="CUDA",
        integrator="variableLangevin",  #variablelangevin, langevinmiddle, verlet, variableverlet, brownian
        error_tol=0.003,
        GPU="1",
        collision_rate=0.03,
        N=N,
        save_decimals=2,
        PBCbox=False, #False --> infinite space, like packman effect.
        reporters=[reporter],
        precision="single", #single, mixed, double / but single recommended. double is really slow (10 times slower...)
        max_Ek=10, #raise error if avg kinetic energy exceeds this value ~ <E> > max_Ek --> raises errorr
        temperature=300, #in the unit of Kelvin #default = 300
        verbose=False, #recommend not to change... if True: --> some many stuffs will come out.
        length_scale=1.0, #scaling factor of the system. length_scale of 1.0 --> harmonic bond has the length scale of 1 nm
        mass=100, #unit : amu, sometimes it can be effective according to Raynolds number.
    )

    """
    Polymer Creation
    """

    polymer = create_polymer(N, polymer_creation_func, method, boxSize=100, r1=10, r2=13, step_size=1.0)

    """
    Data Setting ~ load(s) (a) polymer(s)
    """

    sim.set_data(data=polymer, center=True, random_offset=1e-5, report=True)  #it loads a polymer (set particle positions)
    #center = False / True / "zero"
    #True : move center of mass to zero
    #False : ~ True
    #"zero" : then center the data such as all positions are positive and start at zero

    #random_offset : a little noise

    #sim.set_velocities(v)
    #Langevin and Brownian --> it automatically sets the initial velocity. So don't worry.

    """
    Confinement
    """

    add_confinement(sim, polymer_force_conf, density=density, k=k)

    """
    Polymer Physics
    """
    add_polymer_physics(sim, is_ring = is_ring, trunc = trunc, angle_k = angle_k, bond_length = bond_length, bond_wiggle = bond_wiggle)

    assert polymer.shape[0] == N, "Polymer length does not match N"

    return sim, reporter #return the polymer

# %% [markdown]
# polymer : N x 3 array of the polymer. (coordinates included) ~ array of positions

# %%
#choose the number of monomers
N = 10000
is_ring = False #if False : not a ring, if True : a linear chromosome
trunc = 3.0 #if low, then topoisomerase-like, if high, then no strand crossing

#choose a function for your polymer creation
polymer_creation_func = "grow_cubic" #you can change it manually
#create_spiral(r1, r2, N) : easy mitotic like starting conformation ~ like a sphiral confinement
#create_random_walk(step_size, N) : constrained freely joined chain of length N
#create_constrained_random_walk(N, constraint_f, starting_point, step_size, polar_fixed) : similar to create_random_walk, but with constraint functions
#grow_cubic(N, boxSize, method) : ring / linear polymer on a cubic lattice
method = "standard"
boxSize = 100

#confinement
polymer_force_conf = "spherical_confinement" #making the space!
#spherical_confinement
#cylindrical_confinement
#usually used for nucleus modeling

#spherical_well
#tether_particles
#pull_force
density = 0.85
k = 1.0

#polymer physics
angle_k = 1.5
bond_length = 1.0 #nm
bond_wiggle = 0.05

#max_data_length ~ save every {max_data_length} blocks
max_data_length = 100

# %%
sim, reporter = make_simulation(
    N = N,
    polymer_creation_func = polymer_creation_func,
    method = method,
    boxSize = 100,
    trunc = trunc,
    density = density,
    angle_k = angle_k,
    is_ring = is_ring,
    k = k,
    bond_length = bond_length,
    bond_wiggle = bond_wiggle,
    polymer_force_conf = polymer_force_conf,
    max_data_length = max_data_length
)
# Out:
# Exclude neighbouring chain particles from polynomial_repulsive
# Number of exceptions: 9999

# %%
#number of steps
block_steps = 1000
#timesteps ~ block_timesteps per block
block_timesteps = 100 # ~ 100 integration steps

# %%
sim.local_energy_minimization()
# Out:
# INFO:root:Performing local energy minimization
# INFO:root:adding force spherical_confinement 0
# INFO:root:adding force harmonic_bonds 1
# INFO:root:adding force angle 2
# INFO:root:adding force polynomial_repulsive 3
# INFO:root:Particles loaded. Potential energy is 1.843091
# INFO:root:before minimization eK=1.511043768439465, eP=1.843091241440637, time=0.0 ps
# INFO:root:Particles loaded. Potential energy is 0.549339
# INFO:root:after minimization eK=1.511043768439465, eP=0.3994559562648838, time=0.0 ps

# %%
for _ in range(block_steps):  # Do 10 blocks
    sim.do_block(block_timesteps)  # Of 100 timesteps each. Data is saved automatically.
    
sim.print_stats()  # In the end, print very simple statistics
reporter.dump_data()  # always need to run in the end to dump the block cache to the disk
# Out:
# INFO:root:block    0 pos[1]=[-0.5 -1.9 -1.6] dr=0.69 t=7.2ps kin=1.04 pot=1.36 Rg=10.853 SPS=11418 dt=71.8fs dx=16.34pm
# INFO:root:block    1 pos[1]=[-0.3 -2.0 -1.3] dr=0.85 t=14.4ps kin=1.09 pot=1.49 Rg=11.360 SPS=12131 dt=71.8fs dx=16.74pm
# INFO:root:block    2 pos[1]=[0.2 -1.0 -1.8] dr=0.84 t=21.6ps kin=1.11 pot=1.63 Rg=11.776 SPS=12490 dt=71.8fs dx=16.88pm
# INFO:root:block    3 pos[1]=[0.2 -1.3 -1.5] dr=0.80 t=28.8ps kin=1.14 pot=1.74 Rg=11.998 SPS=12182 dt=71.8fs dx=17.12pm
# INFO:root:block    4 pos[1]=[0.0 -1.1 -2.0] dr=0.80 t=36.0ps kin=1.21 pot=1.82 Rg=12.034 SPS=12638 dt=71.8fs dx=17.62pm
# INFO:root:block    5 pos[1]=[1.0 -1.7 -2.1] dr=0.82 t=43.2ps kin=1.27 pot=1.87 Rg=11.940 SPS=12473 dt=71.8fs dx=18.10pm
# INFO:root:block    6 pos[1]=[0.9 -1.5 -2.2] dr=0.85 t=50.3ps kin=1.34 pot=1.88 Rg=11.785 SPS=12126 dt=71.8fs dx=18.61pm
# INFO:root:block    7 pos[1]=[0.1 -0.1 -2.7] dr=0.86 t=57.5ps kin=1.36 pot=1.92 Rg=11.637 SPS=10708 dt=71.8fs dx=18.69pm
# INFO:root:block    8 pos[1]=[0.6 0.4 -2.5] dr=0.86 t=64.7ps kin=1.37 pot=1.95 Rg=11.561 SPS=12074 dt=71.8fs dx=18.80pm
# INFO:root:block    9 pos[1]=[0.6 -0.2 -2.1] dr=0.86 t=71.9ps kin=1.39 pot=1.97 Rg=11.562 SPS=12250 dt=71.8fs dx=18.93pm
# INFO:root:block   10 pos[1]=[0.8 -1.1 -1.9] dr=0.87 t=79.1ps kin=1.41 pot=1.98 Rg=11.611 SPS=12464 dt=71.8fs dx=19.03pm
# INFO:root:block   11 pos[1]=[0.4 -0.7 -2.2] dr=0.87 t=86.2ps kin=1.43 pot=1.99 Rg=11.687 SPS=12230 dt=71.6fs dx=19.09pm
# INFO:root:block   12 pos[1]=[1.3 -0.5 -2.2] dr=0.88 t=93.4ps kin=1.42 pot=2.01 Rg=11.752 SPS=12516 dt=71.2fs dx=18.96pm
# INFO:root:block   13 pos[1]=[1.9 -0.7 -1.9] dr=0.87 t=100.5ps kin=1.45 pot=2.02 Rg=11.788 SPS=12163 dt=71.0fs dx=19.07pm
# INFO:root:block   14 pos[1]=[1.9 -0.6 -1.8] dr=0.88 t=107.6ps kin=1.44 pot=2.04 Rg=11.789 SPS=12653 dt=70.9fs dx=19.03pm
# INFO:root:block   15 pos[1]=[2.4 0.0 -0.9] dr=0.88 t=114.7ps kin=1.46 pot=2.04 Rg=11.767 SPS=12622 dt=70.7fs dx=19.05pm
# INFO:root:block   16 pos[1]=[2.2 0.5 -1.9] dr=0.89 t=121.7ps kin=1.46 pot=2.04 Rg=11.745 SPS=12215 dt=70.5fs dx=19.02pm
# INFO:root:block   17 pos[1]=[1.8 1.5 -0.7] dr=0.88 t=128.8ps kin=1.47 pot=2.03 Rg=11.733 SPS=12432 dt=70.5fs dx=19.08pm
# INFO:root:block   18 pos[1]=[1.4 1.3 -0.9] dr=0.88 t=135.8ps kin=1.46 pot=2.03 Rg=11.725 SPS=12217 dt=70.5fs dx=19.00pm
# INFO:root:block   19 pos[1]=[1.7 0.7 -0.7] dr=0.87 t=142.9ps kin=1.48 pot=2.03 Rg=11.708 SPS=12572 dt=70.5fs dx=19.16pm
# INFO:root:block   20 pos[1]=[1.4 1.5 -0.4] dr=0.88 t=149.9ps kin=1.47 pot=2.05 Rg=11.693 SPS=12616 dt=70.4fs dx=19.08pm
# INFO:root:block   21 pos[1]=[1.6 1.0 -0.5] dr=0.88 t=157.0ps kin=1.46 pot=2.04 Rg=11.688 SPS=12104 dt=70.4fs dx=19.03pm
# INFO:root:block   22 pos[1]=[1.6 1.2 -0.3] dr=0.87 t=164.0ps kin=1.46 pot=2.05 Rg=11.694 SPS=12668 dt=70.4fs dx=18.98pm
# INFO:root:block   23 pos[1]=[1.1 1.1 -0.5] dr=0.86 t=171.1ps kin=1.46 pot=2.03 Rg=11.704 SPS=12293 dt=70.4fs dx=19.04pm
# INFO:root:block   24 pos[1]=[0.8 1.5 -0.5] dr=0.87 t=178.1ps kin=1.45 pot=2.02 Rg=11.713 SPS=12621 dt=70.4fs dx=18.95pm
# INFO:root:block   25 pos[1]=[1.8 1.0 0.6] dr=0.87 t=185.1ps kin=1.46 pot=2.03 Rg=11.722 SPS=12657 dt=70.4fs dx=18.99pm
# INFO:root:block   26 pos[1]=[2.3 1.0 1.6] dr=0.86 t=192.2ps kin=1.46 pot=2.03 Rg=11.726 SPS=11485 dt=70.4fs dx=18.98pm
# INFO:root:block   27 pos[1]=[2.4 1.5 1.9] dr=0.88 t=199.2ps kin=1.46 pot=2.01 Rg=11.722 SPS=12426 dt=70.4fs dx=19.01pm
# INFO:root:block   28 pos[1]=[2.5 1.6 1.0] dr=0.87 t=206.3ps kin=1.46 pot=2.02 Rg=11.719 SPS=12299 dt=70.4fs dx=19.03pm
# INFO:root:block   29 pos[1]=[2.8 1.6 0.9] dr=0.87 t=213.3ps kin=1.46 pot=2.03 Rg=11.724 SPS=12513 dt=70.4fs dx=18.98pm
# INFO:root:block   30 pos[1]=[3.2 1.4 0.7] dr=0.88 t=220.4ps kin=1.48 pot=2.01 Rg=11.724 SPS=12554 dt=70.4fs dx=19.15pm
# INFO:root:block   31 pos[1]=[3.1 1.0 -0.3] dr=0.88 t=227.4ps kin=1.47 pot=2.03 Rg=11.719 SPS=12291 dt=70.4fs dx=19.08pm
# INFO:root:block   32 pos[1]=[3.7 1.8 -0.5] dr=0.88 t=234.4ps kin=1.45 pot=2.03 Rg=11.717 SPS=12475 dt=70.4fs dx=18.94pm
# INFO:root:block   33 pos[1]=[3.8 1.8 -0.4] dr=0.87 t=241.5ps kin=1.47 pot=2.01 Rg=11.711 SPS=12198 dt=70.4fs dx=19.06pm
# INFO:root:block   34 pos[1]=[3.7 1.1 -0.3] dr=0.88 t=248.5ps kin=1.46 pot=2.01 Rg=11.702 SPS=12444 dt=70.4fs dx=19.00pm
# INFO:root:block   35 pos[1]=[4.0 1.1 -0.8] dr=0.87 t=255.6ps kin=1.47 pot=2.00 Rg=11.702 SPS=12593 dt=70.4fs dx=19.05pm
# INFO:root:block   36 pos[1]=[3.6 1.2 -1.4] dr=0.87 t=262.6ps kin=1.47 pot=1.99 Rg=11.710 SPS=12130 dt=70.4fs dx=19.10pm
# INFO:root:block   37 pos[1]=[3.1 0.8 -0.5] dr=0.87 t=269.6ps kin=1.48 pot=1.99 Rg=11.718 SPS=12302 dt=70.4fs dx=19.12pm
# INFO:root:block   38 pos[1]=[3.6 1.2 -0.1] dr=0.88 t=276.7ps kin=1.45 pot=2.02 Rg=11.722 SPS=12053 dt=70.4fs dx=18.94pm
# INFO:root:block   39 pos[1]=[3.4 0.5 -0.5] dr=0.87 t=283.7ps kin=1.47 pot=2.01 Rg=11.721 SPS=12523 dt=70.4fs dx=19.08pm
# INFO:root:block   40 pos[1]=[2.4 0.2 -1.0] dr=0.88 t=290.8ps kin=1.47 pot=2.01 Rg=11.718 SPS=11126 dt=70.4fs dx=19.08pm
# INFO:root:block   41 pos[1]=[2.9 -0.6 -0.9] dr=0.87 t=297.8ps kin=1.46 pot=2.02 Rg=11.716 SPS=11347 dt=70.4fs dx=19.02pm
# INFO:root:block   42 pos[1]=[4.4 -0.6 -0.8] dr=0.87 t=304.9ps kin=1.47 pot=2.03 Rg=11.715 SPS=12390 dt=70.4fs dx=19.05pm
# INFO:root:block   43 pos[1]=[4.4 -0.1 -1.4] dr=0.88 t=311.9ps kin=1.47 pot=2.02 Rg=11.707 SPS=12245 dt=70.4fs dx=19.09pm
# INFO:root:block   44 pos[1]=[4.7 -0.6 -1.2] dr=0.88 t=318.9ps kin=1.49 pot=2.03 Rg=11.704 SPS=12413 dt=70.4fs dx=19.19pm
# INFO:root:block   45 pos[1]=[4.9 -0.1 -1.1] dr=0.89 t=326.0ps kin=1.49 pot=2.03 Rg=11.704 SPS=12649 dt=70.4fs dx=19.19pm
# INFO:root:block   46 pos[1]=[4.6 0.4 -1.1] dr=0.87 t=333.0ps kin=1.46 pot=2.05 Rg=11.707 SPS=12127 dt=70.4fs dx=18.99pm
# INFO:root:block   47 pos[1]=[4.5 -0.1 -1.2] dr=0.86 t=340.1ps kin=1.46 pot=2.04 Rg=11.706 SPS=12438 dt=70.4fs dx=19.01pm
# INFO:root:block   48 pos[1]=[4.9 0.4 -0.3] dr=0.87 t=347.1ps kin=1.47 pot=2.03 Rg=11.703 SPS=12233 dt=70.4fs dx=19.04pm
# INFO:root:block   49 pos[1]=[5.7 1.6 -1.0] dr=0.87 t=354.2ps kin=1.48 pot=2.02 Rg=11.710 SPS=12534 dt=70.4fs dx=19.15pm
# INFO:root:block   50 pos[1]=[5.7 1.4 -0.5] dr=0.88 t=361.2ps kin=1.47 pot=2.02 Rg=11.708 SPS=12425 dt=70.4fs dx=19.08pm
# INFO:root:block   51 pos[1]=[5.3 1.5 -0.1] dr=0.88 t=368.2ps kin=1.46 pot=2.02 Rg=11.705 SPS=12072 dt=70.4fs dx=19.03pm
# INFO:root:block   52 pos[1]=[5.7 1.6 0.6] dr=0.87 t=375.3ps kin=1.47 pot=2.02 Rg=11.713 SPS=12645 dt=70.4fs dx=19.10pm
# INFO:root:block   53 pos[1]=[5.5 0.3 0.6] dr=0.88 t=382.3ps kin=1.46 pot=2.03 Rg=11.721 SPS=12001 dt=70.4fs dx=19.02pm
# INFO:root:block   54 pos[1]=[5.4 1.8 0.1] dr=0.87 t=389.4ps kin=1.48 pot=2.01 Rg=11.715 SPS=12392 dt=70.4fs dx=19.16pm
# INFO:root:block   55 pos[1]=[4.8 2.9 -0.9] dr=0.88 t=396.4ps kin=1.50 pot=2.01 Rg=11.700 SPS=12277 dt=70.4fs dx=19.24pm
# INFO:root:block   56 pos[1]=[5.2 2.7 -0.6] dr=0.87 t=403.4ps kin=1.47 pot=2.01 Rg=11.698 SPS=12127 dt=70.4fs dx=19.10pm
# INFO:root:block   57 pos[1]=[5.1 2.1 -0.4] dr=0.87 t=410.5ps kin=1.47 pot=2.01 Rg=11.705 SPS=12543 dt=70.4fs dx=19.06pm
# INFO:root:block   58 pos[1]=[5.2 2.4 -0.3] dr=0.88 t=417.5ps kin=1.46 pot=2.03 Rg=11.705 SPS=12083 dt=70.4fs dx=19.01pm
# INFO:root:block   59 pos[1]=[4.6 3.1 -1.4] dr=0.88 t=424.6ps kin=1.47 pot=2.02 Rg=11.705 SPS=12545 dt=70.4fs dx=19.09pm
# INFO:root:block   60 pos[1]=[4.2 3.3 -1.5] dr=0.87 t=431.6ps kin=1.48 pot=2.03 Rg=11.710 SPS=12557 dt=70.4fs dx=19.10pm
# INFO:root:block   61 pos[1]=[3.4 3.2 -1.7] dr=0.86 t=438.6ps kin=1.47 pot=2.03 Rg=11.720 SPS=12005 dt=70.1fs dx=18.99pm
# INFO:root:block   62 pos[1]=[4.3 2.9 -0.9] dr=0.87 t=445.6ps kin=1.48 pot=2.03 Rg=11.727 SPS=12506 dt=70.1fs dx=19.06pm
# INFO:root:block   63 pos[1]=[4.2 2.3 -0.8] dr=0.87 t=452.6ps kin=1.49 pot=2.02 Rg=11.731 SPS=12181 dt=70.1fs dx=19.13pm
# INFO:root:block   64 pos[1]=[4.0 3.1 -0.5] dr=0.88 t=459.7ps kin=1.49 pot=2.02 Rg=11.725 SPS=12643 dt=70.1fs dx=19.14pm
# INFO:root:block   65 pos[1]=[3.6 2.9 -0.8] dr=0.87 t=466.7ps kin=1.48 pot=2.01 Rg=11.713 SPS=12395 dt=70.1fs dx=19.07pm
# INFO:root:block   66 pos[1]=[2.8 2.6 -1.7] dr=0.87 t=473.7ps kin=1.48 pot=2.01 Rg=11.708 SPS=11976 dt=70.1fs dx=19.04pm
# INFO:root:block   67 pos[1]=[3.0 2.5 -0.8] dr=0.87 t=480.7ps kin=1.48 pot=2.00 Rg=11.701 SPS=12514 dt=70.1fs dx=19.02pm
# INFO:root:block   68 pos[1]=[2.0 2.2 -0.7] dr=0.86 t=487.7ps kin=1.47 pot=2.02 Rg=11.698 SPS=11537 dt=70.1fs dx=18.97pm
# INFO:root:block   69 pos[1]=[1.6 1.3 -1.5] dr=0.86 t=494.7ps kin=1.48 pot=2.00 Rg=11.702 SPS=12405 dt=70.1fs dx=19.07pm
# INFO:root:block   70 pos[1]=[2.4 2.1 -1.1] dr=0.88 t=501.7ps kin=1.46 pot=2.01 Rg=11.702 SPS=12606 dt=70.1fs dx=18.92pm
# INFO:root:block   71 pos[1]=[2.1 1.7 -1.2] dr=0.87 t=508.7ps kin=1.47 pot=1.98 Rg=11.692 SPS=12075 dt=70.1fs dx=18.99pm
# INFO:root:block   72 pos[1]=[0.6 0.9 -0.7] dr=0.87 t=515.7ps kin=1.46 pot=1.99 Rg=11.693 SPS=12509 dt=70.1fs dx=18.92pm
# INFO:root:block   73 pos[1]=[1.0 0.9 -0.8] dr=0.88 t=522.8ps kin=1.47 pot=2.00 Rg=11.701 SPS=12100 dt=70.1fs dx=18.98pm
# INFO:root:block   74 pos[1]=[0.7 -0.2 -0.8] dr=0.87 t=529.8ps kin=1.47 pot=2.01 Rg=11.715 SPS=12641 dt=70.1fs dx=18.96pm
# INFO:root:block   75 pos[1]=[0.0 -0.8 -0.1] dr=0.88 t=536.8ps kin=1.47 pot=2.02 Rg=11.726 SPS=12806 dt=70.1fs dx=18.96pm
# INFO:root:block   76 pos[1]=[0.0 -0.4 -0.7] dr=0.87 t=543.8ps kin=1.48 pot=2.02 Rg=11.725 SPS=12247 dt=70.1fs dx=19.04pm
# INFO:root:block   77 pos[1]=[-0.7 0.0 -1.2] dr=0.88 t=550.8ps kin=1.47 pot=2.03 Rg=11.722 SPS=12396 dt=70.1fs dx=19.01pm
# INFO:root:block   78 pos[1]=[-0.6 -0.8 -2.3] dr=0.88 t=557.8ps kin=1.49 pot=2.03 Rg=11.737 SPS=12079 dt=70.1fs dx=19.11pm
# INFO:root:block   79 pos[1]=[-0.1 -0.5 -1.5] dr=0.89 t=564.8ps kin=1.48 pot=2.04 Rg=11.747 SPS=12150 dt=70.1fs dx=19.05pm
# INFO:root:block   80 pos[1]=[-0.3 -0.3 -2.0] dr=0.88 t=571.8ps kin=1.48 pot=2.04 Rg=11.747 SPS=12213 dt=70.1fs dx=19.08pm
# INFO:root:block   81 pos[1]=[-0.1 0.5 -1.9] dr=0.88 t=578.8ps kin=1.47 pot=2.05 Rg=11.743 SPS=12007 dt=70.1fs dx=18.98pm
# INFO:root:block   82 pos[1]=[0.6 0.2 -1.3] dr=0.88 t=585.9ps kin=1.49 pot=2.03 Rg=11.737 SPS=12424 dt=70.1fs dx=19.13pm
# INFO:root:block   83 pos[1]=[1.2 0.6 -1.1] dr=0.88 t=592.9ps kin=1.49 pot=2.03 Rg=11.715 SPS=12024 dt=70.1fs dx=19.09pm
# INFO:root:block   84 pos[1]=[1.0 0.5 -1.0] dr=0.87 t=599.9ps kin=1.47 pot=2.04 Rg=11.697 SPS=12487 dt=70.1fs dx=18.95pm
# INFO:root:block   85 pos[1]=[-0.3 -0.1 -1.5] dr=0.87 t=606.9ps kin=1.48 pot=2.02 Rg=11.695 SPS=12423 dt=70.1fs dx=19.06pm
# INFO:root:block   86 pos[1]=[0.3 -0.4 -1.5] dr=0.87 t=613.9ps kin=1.46 pot=2.03 Rg=11.707 SPS=11988 dt=70.1fs dx=18.95pm
# INFO:root:block   87 pos[1]=[0.1 -0.4 -1.3] dr=0.86 t=620.9ps kin=1.47 pot=2.02 Rg=11.712 SPS=12344 dt=70.1fs dx=18.97pm
# INFO:root:block   88 pos[1]=[-1.1 -0.3 -1.9] dr=0.86 t=627.9ps kin=1.50 pot=2.01 Rg=11.721 SPS=12016 dt=70.1fs dx=19.15pm
# INFO:root:block   89 pos[1]=[-1.2 -0.2 -2.6] dr=0.87 t=634.9ps kin=1.48 pot=2.01 Rg=11.738 SPS=12649 dt=70.1fs dx=19.08pm
# INFO:root:block   90 pos[1]=[-0.2 0.9 -1.3] dr=0.88 t=641.9ps kin=1.51 pot=2.00 Rg=11.744 SPS=12646 dt=70.1fs dx=19.22pm
# INFO:root:block   91 pos[1]=[-0.8 0.5 -1.6] dr=0.88 t=649.0ps kin=1.50 pot=2.01 Rg=11.729 SPS=11951 dt=70.1fs dx=19.19pm
# INFO:root:block   92 pos[1]=[-0.9 1.3 -0.8] dr=0.88 t=656.0ps kin=1.50 pot=2.01 Rg=11.706 SPS=12688 dt=70.1fs dx=19.15pm
# INFO:root:block   93 pos[1]=[-0.3 1.7 -2.0] dr=0.87 t=663.0ps kin=1.48 pot=2.03 Rg=11.680 SPS=12052 dt=70.1fs dx=19.08pm
# INFO:root:block   94 pos[1]=[-0.2 1.2 -2.1] dr=0.87 t=670.0ps kin=1.48 pot=2.02 Rg=11.672 SPS=12448 dt=70.1fs dx=19.04pm
# INFO:root:block   95 pos[1]=[-0.0 0.4 -2.3] dr=0.88 t=677.0ps kin=1.47 pot=2.03 Rg=11.689 SPS=12476 dt=70.1fs dx=18.98pm
# INFO:root:block   96 pos[1]=[0.2 -0.6 -3.2] dr=0.88 t=684.0ps kin=1.48 pot=2.00 Rg=11.726 SPS=11733 dt=70.1fs dx=19.06pm
# INFO:root:block   97 pos[1]=[1.1 -0.8 -2.9] dr=0.88 t=691.0ps kin=1.47 pot=2.02 Rg=11.750 SPS=12365 dt=70.1fs dx=18.96pm
# INFO:root:block   98 pos[1]=[1.0 -0.4 -2.6] dr=0.87 t=698.0ps kin=1.47 pot=2.00 Rg=11.739 SPS=11904 dt=70.1fs dx=18.99pm
# INFO:root:block   99 pos[1]=[1.9 -0.1 -3.3] dr=0.87 t=705.0ps kin=1.47 pot=2.02 Rg=11.714 SPS=12011 dt=70.1fs dx=18.95pm
# INFO:root:block  100 pos[1]=[1.3 0.0 -3.5] dr=0.87 t=712.1ps kin=1.47 pot=2.01 Rg=11.700 SPS=12287 dt=70.1fs dx=19.00pm
# INFO:root:block  101 pos[1]=[1.1 0.3 -3.5] dr=0.87 t=719.1ps kin=1.48 pot=2.01 Rg=11.690 SPS=12222 dt=70.1fs dx=19.04pm
# INFO:root:block  102 pos[1]=[0.2 -0.1 -3.2] dr=0.87 t=726.1ps kin=1.48 pot=2.01 Rg=11.682 SPS=12402 dt=70.1fs dx=19.05pm
# INFO:root:block  103 pos[1]=[-1.1 0.2 -3.9] dr=0.88 t=733.1ps kin=1.48 pot=1.99 Rg=11.693 SPS=12312 dt=70.1fs dx=19.07pm
# INFO:root:block  104 pos[1]=[-1.4 -0.5 -4.1] dr=0.87 t=740.1ps kin=1.45 pot=2.01 Rg=11.709 SPS=12404 dt=70.1fs dx=18.87pm
# INFO:root:block  105 pos[1]=[-1.4 -1.5 -4.4] dr=0.87 t=747.1ps kin=1.47 pot=2.00 Rg=11.724 SPS=12504 dt=70.1fs dx=18.95pm
# INFO:root:block  106 pos[1]=[-1.1 -1.7 -2.9] dr=0.87 t=754.1ps kin=1.46 pot=1.98 Rg=11.723 SPS=12265 dt=70.1fs dx=18.94pm
# INFO:root:block  107 pos[1]=[-0.2 -3.3 -3.0] dr=0.87 t=761.1ps kin=1.45 pot=1.98 Rg=11.717 SPS=12497 dt=70.1fs dx=18.89pm
# INFO:root:block  108 pos[1]=[-0.0 -3.2 -3.8] dr=0.86 t=768.1ps kin=1.44 pot=1.99 Rg=11.707 SPS=12221 dt=70.1fs dx=18.80pm
# INFO:root:block  109 pos[1]=[-0.0 -3.0 -5.0] dr=0.86 t=775.2ps kin=1.44 pot=1.99 Rg=11.699 SPS=12368 dt=70.1fs dx=18.80pm
# INFO:root:block  110 pos[1]=[0.4 -2.8 -4.0] dr=0.86 t=782.2ps kin=1.44 pot=2.00 Rg=11.705 SPS=12512 dt=70.1fs dx=18.76pm
# INFO:root:block  111 pos[1]=[0.3 -2.5 -4.2] dr=0.87 t=789.2ps kin=1.45 pot=1.99 Rg=11.722 SPS=12054 dt=70.1fs dx=18.84pm
# INFO:root:block  112 pos[1]=[-0.8 -2.2 -3.9] dr=0.87 t=796.2ps kin=1.45 pot=1.99 Rg=11.732 SPS=12344 dt=70.1fs dx=18.82pm
# INFO:root:block  113 pos[1]=[-0.4 -2.9 -3.7] dr=0.87 t=803.2ps kin=1.44 pot=1.99 Rg=11.730 SPS=12188 dt=70.1fs dx=18.80pm
# INFO:root:block  114 pos[1]=[-0.1 -3.1 -3.4] dr=0.87 t=810.2ps kin=1.46 pot=1.98 Rg=11.722 SPS=12506 dt=70.1fs dx=18.93pm
# INFO:root:block  115 pos[1]=[0.0 -2.7 -3.6] dr=0.87 t=817.2ps kin=1.47 pot=1.97 Rg=11.715 SPS=12454 dt=70.1fs dx=18.97pm
# INFO:root:block  116 pos[1]=[-1.0 -1.7 -3.6] dr=0.87 t=824.2ps kin=1.46 pot=1.99 Rg=11.700 SPS=12109 dt=70.1fs dx=18.93pm
# INFO:root:block  117 pos[1]=[-0.4 -1.4 -3.5] dr=0.86 t=831.2ps kin=1.45 pot=1.99 Rg=11.683 SPS=11550 dt=70.1fs dx=18.87pm
# INFO:root:block  118 pos[1]=[1.4 -0.9 -2.9] dr=0.85 t=838.3ps kin=1.46 pot=1.97 Rg=11.681 SPS=11273 dt=70.1fs dx=18.94pm
# INFO:root:block  119 pos[1]=[2.1 -0.9 -2.3] dr=0.86 t=845.3ps kin=1.47 pot=1.98 Rg=11.683 SPS=12308 dt=70.1fs dx=18.99pm
# INFO:root:block  120 pos[1]=[2.4 -1.0 -2.2] dr=0.87 t=852.3ps kin=1.47 pot=1.99 Rg=11.699 SPS=12264 dt=70.1fs dx=18.98pm
# INFO:root:block  121 pos[1]=[3.4 0.2 -2.1] dr=0.86 t=859.3ps kin=1.47 pot=2.00 Rg=11.710 SPS=11835 dt=70.1fs dx=18.99pm
# INFO:root:block  122 pos[1]=[3.3 -0.1 -2.3] dr=0.86 t=866.3ps kin=1.45 pot=2.01 Rg=11.715 SPS=11495 dt=70.1fs dx=18.88pm
# INFO:root:block  123 pos[1]=[2.6 -0.2 -1.9] dr=0.87 t=873.3ps kin=1.47 pot=1.99 Rg=11.718 SPS=12433 dt=70.1fs dx=18.98pm
# INFO:root:block  124 pos[1]=[2.7 -1.1 -1.7] dr=0.87 t=880.3ps kin=1.47 pot=2.01 Rg=11.720 SPS=12073 dt=70.1fs dx=18.97pm
# INFO:root:block  125 pos[1]=[2.7 -0.3 -1.6] dr=0.87 t=887.3ps kin=1.50 pot=1.98 Rg=11.716 SPS=11820 dt=70.1fs dx=19.17pm
# INFO:root:block  126 pos[1]=[1.7 -1.3 -2.3] dr=0.87 t=894.3ps kin=1.48 pot=2.01 Rg=11.706 SPS=11550 dt=70.1fs dx=19.08pm
# INFO:root:block  127 pos[1]=[1.6 -2.6 -2.2] dr=0.88 t=901.4ps kin=1.50 pot=2.02 Rg=11.690 SPS=11574 dt=70.1fs dx=19.20pm
# INFO:root:block  128 pos[1]=[1.9 -1.9 -1.9] dr=0.88 t=908.4ps kin=1.49 pot=2.02 Rg=11.690 SPS=11842 dt=70.1fs dx=19.14pm
# INFO:root:block  129 pos[1]=[0.8 -1.8 -1.8] dr=0.87 t=915.4ps kin=1.48 pot=2.01 Rg=11.704 SPS=11193 dt=70.1fs dx=19.04pm
# INFO:root:block  130 pos[1]=[-0.3 -1.8 -2.7] dr=0.87 t=922.4ps kin=1.48 pot=2.01 Rg=11.711 SPS=11486 dt=70.1fs dx=19.06pm
# INFO:root:block  131 pos[1]=[-0.2 -2.4 -1.7] dr=0.88 t=929.4ps kin=1.48 pot=2.02 Rg=11.712 SPS=11218 dt=70.1fs dx=19.07pm
# INFO:root:block  132 pos[1]=[-0.2 -2.4 -1.5] dr=0.87 t=936.4ps kin=1.48 pot=2.00 Rg=11.721 SPS=11471 dt=70.1fs dx=19.03pm
# INFO:root:block  133 pos[1]=[-0.6 -3.0 -2.1] dr=0.86 t=943.4ps kin=1.45 pot=2.01 Rg=11.738 SPS=11469 dt=70.1fs dx=18.89pm
# INFO:root:block  134 pos[1]=[-0.7 -2.1 -1.2] dr=0.87 t=950.4ps kin=1.48 pot=2.00 Rg=11.744 SPS=11099 dt=70.1fs dx=19.03pm
# INFO:root:block  135 pos[1]=[-0.6 -0.9 -1.5] dr=0.88 t=957.4ps kin=1.49 pot=2.00 Rg=11.728 SPS=11584 dt=70.1fs dx=19.09pm
# INFO:root:block  136 pos[1]=[-1.8 -1.4 -1.2] dr=0.88 t=964.5ps kin=1.48 pot=2.01 Rg=11.709 SPS=11304 dt=70.1fs dx=19.04pm
# INFO:root:block  137 pos[1]=[-1.1 -1.9 -0.6] dr=0.88 t=971.5ps kin=1.49 pot=1.99 Rg=11.687 SPS=11311 dt=70.1fs dx=19.12pm
# INFO:root:block  138 pos[1]=[0.1 -2.7 -0.2] dr=0.88 t=978.5ps kin=1.49 pot=2.00 Rg=11.675 SPS=11253 dt=70.1fs dx=19.09pm
# INFO:root:block  139 pos[1]=[-0.7 -2.2 0.2] dr=0.87 t=985.5ps kin=1.48 pot=2.02 Rg=11.677 SPS=11424 dt=70.1fs dx=19.03pm
# INFO:root:block  140 pos[1]=[-0.7 -1.5 0.0] dr=0.87 t=992.5ps kin=1.48 pot=2.00 Rg=11.691 SPS=11773 dt=70.1fs dx=19.06pm
# INFO:root:block  141 pos[1]=[-0.3 -1.2 -0.4] dr=0.88 t=999.5ps kin=1.47 pot=2.00 Rg=11.697 SPS=11156 dt=70.1fs dx=18.96pm
# INFO:root:block  142 pos[1]=[-0.3 -0.8 -0.9] dr=0.87 t=1006.5ps kin=1.48 pot=1.99 Rg=11.698 SPS=11646 dt=70.1fs dx=19.02pm
# INFO:root:block  143 pos[1]=[-0.2 -2.0 -0.6] dr=0.86 t=1013.5ps kin=1.49 pot=1.98 Rg=11.695 SPS=11690 dt=70.1fs dx=19.14pm
# INFO:root:block  144 pos[1]=[-0.2 -2.2 -0.7] dr=0.87 t=1020.5ps kin=1.47 pot=1.99 Rg=11.708 SPS=11253 dt=70.1fs dx=19.01pm
# INFO:root:block  145 pos[1]=[-0.2 -2.1 -0.6] dr=0.86 t=1027.6ps kin=1.46 pot=2.00 Rg=11.726 SPS=12153 dt=70.1fs dx=18.93pm
# INFO:root:block  146 pos[1]=[0.3 -1.5 -1.1] dr=0.87 t=1034.6ps kin=1.49 pot=1.99 Rg=11.737 SPS=11801 dt=70.1fs dx=19.14pm
# INFO:root:block  147 pos[1]=[0.7 -0.7 -1.8] dr=0.87 t=1041.6ps kin=1.48 pot=2.01 Rg=11.731 SPS=12275 dt=70.1fs dx=19.05pm
# INFO:root:block  148 pos[1]=[0.3 -0.6 -0.8] dr=0.87 t=1048.6ps kin=1.49 pot=2.00 Rg=11.713 SPS=12468 dt=70.1fs dx=19.11pm
# INFO:root:block  149 pos[1]=[0.2 -0.1 -1.0] dr=0.87 t=1055.6ps kin=1.47 pot=1.98 Rg=11.695 SPS=12165 dt=70.1fs dx=19.01pm
# INFO:root:block  150 pos[1]=[-0.0 0.0 -0.4] dr=0.86 t=1062.6ps kin=1.47 pot=1.99 Rg=11.684 SPS=12064 dt=70.1fs dx=18.96pm
# INFO:root:block  151 pos[1]=[-0.4 0.7 0.1] dr=0.86 t=1069.6ps kin=1.47 pot=1.98 Rg=11.690 SPS=11414 dt=70.1fs dx=18.96pm
# INFO:root:block  152 pos[1]=[-0.4 0.8 1.0] dr=0.85 t=1076.6ps kin=1.48 pot=1.98 Rg=11.711 SPS=11687 dt=70.1fs dx=19.03pm
# INFO:root:block  153 pos[1]=[-0.2 0.1 1.1] dr=0.86 t=1083.6ps kin=1.47 pot=1.99 Rg=11.714 SPS=11448 dt=70.1fs dx=18.98pm
# INFO:root:block  154 pos[1]=[0.3 -0.3 1.3] dr=0.86 t=1090.7ps kin=1.49 pot=1.99 Rg=11.718 SPS=11197 dt=70.1fs dx=19.12pm
# INFO:root:block  155 pos[1]=[-0.2 -0.3 1.3] dr=0.86 t=1097.7ps kin=1.48 pot=2.00 Rg=11.726 SPS=11701 dt=70.1fs dx=19.08pm
# INFO:root:block  156 pos[1]=[0.1 1.3 1.4] dr=0.87 t=1104.7ps kin=1.48 pot=2.01 Rg=11.738 SPS=11810 dt=70.1fs dx=19.03pm
# INFO:root:block  157 pos[1]=[-1.4 1.9 2.5] dr=0.87 t=1111.7ps kin=1.47 pot=2.01 Rg=11.735 SPS=11567 dt=70.1fs dx=18.99pm
# INFO:root:block  158 pos[1]=[-1.6 1.8 2.2] dr=0.87 t=1118.7ps kin=1.48 pot=2.01 Rg=11.727 SPS=11442 dt=70.1fs dx=19.06pm
# INFO:root:block  159 pos[1]=[-1.8 2.5 2.2] dr=0.87 t=1125.7ps kin=1.48 pot=2.01 Rg=11.725 SPS=11547 dt=70.1fs dx=19.03pm
# INFO:root:block  160 pos[1]=[-1.0 1.7 2.9] dr=0.86 t=1132.7ps kin=1.46 pot=2.02 Rg=11.724 SPS=11838 dt=70.1fs dx=18.94pm
# INFO:root:block  161 pos[1]=[-0.2 1.9 3.3] dr=0.88 t=1139.7ps kin=1.48 pot=2.03 Rg=11.718 SPS=11379 dt=70.1fs dx=19.05pm
# INFO:root:block  162 pos[1]=[0.1 1.4 2.7] dr=0.87 t=1146.7ps kin=1.49 pot=2.02 Rg=11.712 SPS=11713 dt=70.1fs dx=19.12pm
# INFO:root:block  163 pos[1]=[0.0 2.3 2.0] dr=0.88 t=1153.7ps kin=1.49 pot=2.01 Rg=11.705 SPS=11846 dt=70.1fs dx=19.10pm
# INFO:root:block  164 pos[1]=[-0.1 2.8 1.9] dr=0.87 t=1160.8ps kin=1.50 pot=1.99 Rg=11.703 SPS=11592 dt=70.1fs dx=19.17pm
# INFO:root:block  165 pos[1]=[-0.1 2.5 2.3] dr=0.87 t=1167.8ps kin=1.48 pot=2.02 Rg=11.711 SPS=11840 dt=70.1fs dx=19.05pm
# INFO:root:block  166 pos[1]=[1.2 1.8 2.2] dr=0.87 t=1174.8ps kin=1.48 pot=2.01 Rg=11.713 SPS=11560 dt=70.1fs dx=19.03pm
# INFO:root:block  167 pos[1]=[0.7 1.4 1.8] dr=0.87 t=1181.8ps kin=1.47 pot=2.00 Rg=11.707 SPS=12259 dt=70.1fs dx=18.98pm
# INFO:root:block  168 pos[1]=[0.8 0.7 2.0] dr=0.87 t=1188.8ps kin=1.46 pot=2.01 Rg=11.701 SPS=11356 dt=70.1fs dx=18.90pm
# INFO:root:block  169 pos[1]=[0.5 0.0 1.5] dr=0.86 t=1195.8ps kin=1.46 pot=1.99 Rg=11.696 SPS=11873 dt=70.1fs dx=18.89pm
# INFO:root:block  170 pos[1]=[-0.0 0.1 1.9] dr=0.86 t=1202.8ps kin=1.46 pot=1.98 Rg=11.696 SPS=12275 dt=70.1fs dx=18.93pm
# INFO:root:block  171 pos[1]=[1.0 0.7 2.8] dr=0.87 t=1209.8ps kin=1.46 pot=1.97 Rg=11.698 SPS=11143 dt=70.1fs dx=18.95pm
# INFO:root:block  172 pos[1]=[0.6 1.4 2.7] dr=0.86 t=1216.8ps kin=1.47 pot=1.98 Rg=11.699 SPS=12271 dt=70.1fs dx=18.97pm
# INFO:root:block  173 pos[1]=[1.1 1.3 2.1] dr=0.87 t=1223.9ps kin=1.47 pot=1.98 Rg=11.703 SPS=11790 dt=70.1fs dx=18.98pm
# INFO:root:block  174 pos[1]=[0.7 2.3 0.9] dr=0.86 t=1230.9ps kin=1.48 pot=1.98 Rg=11.709 SPS=11872 dt=70.1fs dx=19.02pm
# INFO:root:block  175 pos[1]=[0.1 2.2 1.0] dr=0.86 t=1237.9ps kin=1.46 pot=2.00 Rg=11.717 SPS=12212 dt=70.1fs dx=18.94pm
# INFO:root:block  176 pos[1]=[-0.9 2.8 0.8] dr=0.86 t=1244.9ps kin=1.49 pot=1.98 Rg=11.728 SPS=11999 dt=70.1fs dx=19.09pm
# INFO:root:block  177 pos[1]=[-0.6 2.4 0.8] dr=0.86 t=1251.9ps kin=1.47 pot=2.01 Rg=11.730 SPS=12196 dt=70.1fs dx=18.96pm
# INFO:root:block  178 pos[1]=[0.1 1.4 1.1] dr=0.87 t=1258.9ps kin=1.47 pot=2.00 Rg=11.729 SPS=12069 dt=70.1fs dx=19.02pm
# INFO:root:block  179 pos[1]=[-0.2 1.6 0.7] dr=0.87 t=1265.9ps kin=1.49 pot=2.00 Rg=11.719 SPS=11936 dt=70.1fs dx=19.13pm
# INFO:root:block  180 pos[1]=[-0.8 1.4 1.0] dr=0.88 t=1272.9ps kin=1.48 pot=1.99 Rg=11.718 SPS=12019 dt=70.1fs dx=19.06pm
# INFO:root:block  181 pos[1]=[-0.7 0.1 1.2] dr=0.88 t=1279.9ps kin=1.48 pot=2.00 Rg=11.713 SPS=11495 dt=70.1fs dx=19.05pm
# INFO:root:block  182 pos[1]=[-1.5 0.1 1.4] dr=0.86 t=1287.0ps kin=1.47 pot=2.00 Rg=11.716 SPS=11920 dt=70.1fs dx=18.99pm
# INFO:root:block  183 pos[1]=[-1.7 -0.0 1.5] dr=0.87 t=1294.0ps kin=1.48 pot=2.00 Rg=11.713 SPS=11900 dt=70.1fs dx=19.05pm
# INFO:root:block  184 pos[1]=[-1.6 0.7 1.3] dr=0.87 t=1301.0ps kin=1.47 pot=2.00 Rg=11.706 SPS=11628 dt=70.1fs dx=18.98pm
# INFO:root:block  185 pos[1]=[-1.2 -0.1 1.0] dr=0.87 t=1308.0ps kin=1.45 pot=2.02 Rg=11.699 SPS=11333 dt=70.1fs dx=18.88pm
# INFO:root:block  186 pos[1]=[-1.7 -0.3 0.9] dr=0.87 t=1315.0ps kin=1.47 pot=1.99 Rg=11.707 SPS=11162 dt=70.1fs dx=19.00pm
# INFO:root:block  187 pos[1]=[-1.2 -0.2 1.0] dr=0.87 t=1322.0ps kin=1.46 pot=2.00 Rg=11.709 SPS=11503 dt=70.1fs dx=18.91pm
# INFO:root:block  188 pos[1]=[-0.9 -0.4 -0.2] dr=0.87 t=1329.0ps kin=1.46 pot=2.01 Rg=11.707 SPS=11507 dt=70.1fs dx=18.90pm
# INFO:root:block  189 pos[1]=[-0.6 1.0 0.7] dr=0.87 t=1336.0ps kin=1.47 pot=2.00 Rg=11.694 SPS=10978 dt=70.1fs dx=18.99pm
# INFO:root:block  190 pos[1]=[-1.6 1.9 1.7] dr=0.86 t=1343.0ps kin=1.48 pot=2.00 Rg=11.696 SPS=11817 dt=70.1fs dx=19.02pm
# INFO:root:block  191 pos[1]=[-1.3 2.3 1.5] dr=0.87 t=1350.1ps kin=1.46 pot=1.99 Rg=11.696 SPS=11218 dt=70.1fs dx=18.95pm
# INFO:root:block  192 pos[1]=[-1.5 2.8 0.4] dr=0.87 t=1357.1ps kin=1.47 pot=1.99 Rg=11.694 SPS=11691 dt=70.1fs dx=18.96pm
# INFO:root:block  193 pos[1]=[-1.8 2.2 -0.1] dr=0.86 t=1364.1ps kin=1.45 pot=2.00 Rg=11.698 SPS=11688 dt=70.1fs dx=18.85pm
# INFO:root:block  194 pos[1]=[-1.9 1.2 0.6] dr=0.86 t=1371.1ps kin=1.46 pot=1.99 Rg=11.706 SPS=11304 dt=70.1fs dx=18.93pm
# INFO:root:block  195 pos[1]=[-2.1 2.7 1.4] dr=0.87 t=1378.1ps kin=1.45 pot=1.99 Rg=11.708 SPS=11634 dt=70.1fs dx=18.88pm
# INFO:root:block  196 pos[1]=[-1.7 2.4 0.7] dr=0.87 t=1385.1ps kin=1.46 pot=1.99 Rg=11.708 SPS=11444 dt=70.1fs dx=18.95pm
# INFO:root:block  197 pos[1]=[-1.9 2.6 0.9] dr=0.87 t=1392.1ps kin=1.49 pot=1.99 Rg=11.707 SPS=12007 dt=70.1fs dx=19.11pm
# INFO:root:block  198 pos[1]=[-2.0 2.3 0.9] dr=0.87 t=1399.1ps kin=1.49 pot=2.00 Rg=11.700 SPS=11788 dt=70.1fs dx=19.11pm
# INFO:root:block  199 pos[1]=[-2.1 1.5 0.5] dr=0.87 t=1406.1ps kin=1.48 pot=2.01 Rg=11.693 SPS=10662 dt=70.1fs dx=19.03pm
# INFO:root:block  200 pos[1]=[-3.3 2.2 0.8] dr=0.87 t=1413.2ps kin=1.48 pot=2.00 Rg=11.686 SPS=11915 dt=70.1fs dx=19.05pm
# INFO:root:block  201 pos[1]=[-3.9 2.9 1.1] dr=0.87 t=1420.2ps kin=1.48 pot=1.99 Rg=11.693 SPS=11340 dt=70.1fs dx=19.08pm
# INFO:root:block  202 pos[1]=[-4.1 2.4 2.0] dr=0.87 t=1427.2ps kin=1.47 pot=2.01 Rg=11.704 SPS=11516 dt=70.1fs dx=19.00pm
# INFO:root:block  203 pos[1]=[-4.0 2.4 1.4] dr=0.87 t=1434.2ps kin=1.47 pot=2.02 Rg=11.716 SPS=11586 dt=70.1fs dx=19.01pm
# INFO:root:block  204 pos[1]=[-4.7 1.7 0.4] dr=0.87 t=1441.2ps kin=1.47 pot=2.01 Rg=11.712 SPS=11900 dt=70.1fs dx=19.02pm
# INFO:root:block  205 pos[1]=[-4.1 2.0 0.2] dr=0.86 t=1448.2ps kin=1.46 pot=2.01 Rg=11.702 SPS=12381 dt=70.1fs dx=18.91pm
# INFO:root:block  206 pos[1]=[-4.4 1.3 -0.4] dr=0.86 t=1455.2ps kin=1.47 pot=2.00 Rg=11.702 SPS=11599 dt=70.1fs dx=18.96pm
# INFO:root:block  207 pos[1]=[-5.7 0.2 -0.8] dr=0.86 t=1462.2ps kin=1.47 pot=2.00 Rg=11.715 SPS=11564 dt=70.1fs dx=19.00pm
# INFO:root:block  208 pos[1]=[-6.8 1.0 -0.8] dr=0.86 t=1469.2ps kin=1.48 pot=1.99 Rg=11.713 SPS=11776 dt=70.1fs dx=19.07pm
# INFO:root:block  209 pos[1]=[-7.2 0.6 -1.0] dr=0.87 t=1476.3ps kin=1.47 pot=1.99 Rg=11.697 SPS=11970 dt=70.1fs dx=19.00pm
# INFO:root:block  210 pos[1]=[-7.4 0.0 0.3] dr=0.87 t=1483.3ps kin=1.46 pot=1.99 Rg=11.679 SPS=11801 dt=70.1fs dx=18.95pm
# INFO:root:block  211 pos[1]=[-7.0 0.1 0.7] dr=0.86 t=1490.3ps kin=1.47 pot=2.00 Rg=11.680 SPS=11327 dt=70.1fs dx=18.99pm
# INFO:root:block  212 pos[1]=[-6.2 -0.3 0.6] dr=0.86 t=1497.3ps kin=1.48 pot=2.00 Rg=11.696 SPS=11536 dt=70.1fs dx=19.07pm
# INFO:root:block  213 pos[1]=[-5.6 -1.0 0.8] dr=0.86 t=1504.3ps kin=1.48 pot=1.99 Rg=11.717 SPS=11636 dt=70.1fs dx=19.02pm
# INFO:root:block  214 pos[1]=[-5.2 -2.1 0.2] dr=0.86 t=1511.3ps kin=1.48 pot=1.99 Rg=11.729 SPS=11435 dt=70.1fs dx=19.06pm
# INFO:root:block  215 pos[1]=[-5.3 -1.8 0.6] dr=0.87 t=1518.3ps kin=1.47 pot=2.00 Rg=11.718 SPS=11387 dt=70.1fs dx=18.96pm
# INFO:root:block  216 pos[1]=[-4.4 -0.9 0.9] dr=0.87 t=1525.3ps kin=1.47 pot=1.99 Rg=11.701 SPS=11073 dt=70.1fs dx=19.01pm
# INFO:root:block  217 pos[1]=[-4.9 -0.9 0.3] dr=0.87 t=1532.3ps kin=1.47 pot=1.99 Rg=11.692 SPS=11337 dt=70.1fs dx=19.00pm
# INFO:root:block  218 pos[1]=[-4.4 -0.2 0.6] dr=0.86 t=1539.4ps kin=1.45 pot=2.01 Rg=11.699 SPS=11311 dt=70.1fs dx=18.87pm
# INFO:root:block  219 pos[1]=[-4.4 -0.3 -0.4] dr=0.87 t=1546.4ps kin=1.46 pot=2.00 Rg=11.708 SPS=11084 dt=70.1fs dx=18.92pm
# INFO:root:block  220 pos[1]=[-3.5 0.4 -1.1] dr=0.86 t=1553.4ps kin=1.48 pot=1.99 Rg=11.702 SPS=11383 dt=70.1fs dx=19.04pm
# INFO:root:block  221 pos[1]=[-3.3 -0.2 -0.9] dr=0.87 t=1560.4ps kin=1.48 pot=2.00 Rg=11.690 SPS=11302 dt=70.0fs dx=19.00pm
# INFO:root:block  222 pos[1]=[-2.9 -0.8 -1.1] dr=0.87 t=1567.4ps kin=1.47 pot=2.00 Rg=11.685 SPS=11778 dt=70.0fs dx=18.97pm
# INFO:root:block  223 pos[1]=[-2.8 -0.4 -0.9] dr=0.86 t=1574.4ps kin=1.47 pot=2.00 Rg=11.697 SPS=11420 dt=70.0fs dx=18.94pm
# INFO:root:block  224 pos[1]=[-3.7 -1.4 0.3] dr=0.86 t=1581.4ps kin=1.48 pot=2.02 Rg=11.708 SPS=11123 dt=70.0fs dx=19.00pm
# INFO:root:block  225 pos[1]=[-2.8 -2.2 1.1] dr=0.87 t=1588.4ps kin=1.48 pot=2.02 Rg=11.716 SPS=11526 dt=70.0fs dx=19.00pm
# INFO:root:block  226 pos[1]=[-3.6 -0.9 0.2] dr=0.87 t=1595.4ps kin=1.49 pot=2.01 Rg=11.718 SPS=11175 dt=70.0fs dx=19.09pm
# INFO:root:block  227 pos[1]=[-2.8 0.3 -0.3] dr=0.87 t=1602.4ps kin=1.47 pot=2.02 Rg=11.714 SPS=11462 dt=70.0fs dx=18.99pm
# INFO:root:block  228 pos[1]=[-3.5 -0.4 -0.9] dr=0.87 t=1609.4ps kin=1.49 pot=1.99 Rg=11.708 SPS=10674 dt=70.0fs dx=19.09pm
# INFO:root:block  229 pos[1]=[-3.8 -0.2 0.1] dr=0.87 t=1616.4ps kin=1.50 pot=2.01 Rg=11.701 SPS=11293 dt=70.0fs dx=19.14pm
# INFO:root:block  230 pos[1]=[-3.2 -0.2 -0.1] dr=0.87 t=1623.4ps kin=1.48 pot=2.02 Rg=11.697 SPS=11442 dt=70.0fs dx=19.05pm
# INFO:root:block  231 pos[1]=[-2.4 -0.6 -0.9] dr=0.87 t=1630.4ps kin=1.48 pot=2.02 Rg=11.700 SPS=10950 dt=70.0fs dx=19.04pm
# INFO:root:block  232 pos[1]=[-3.0 -0.4 -1.5] dr=0.87 t=1637.4ps kin=1.48 pot=2.02 Rg=11.707 SPS=11494 dt=70.0fs dx=19.05pm
# INFO:root:block  233 pos[1]=[-2.4 -1.1 -1.2] dr=0.87 t=1644.4ps kin=1.49 pot=2.02 Rg=11.718 SPS=11627 dt=70.0fs dx=19.09pm
# INFO:root:block  234 pos[1]=[-2.1 -0.5 -0.9] dr=0.87 t=1651.4ps kin=1.48 pot=2.02 Rg=11.722 SPS=11405 dt=70.0fs dx=19.03pm
# INFO:root:block  235 pos[1]=[-2.5 0.8 -1.6] dr=0.87 t=1658.4ps kin=1.49 pot=2.00 Rg=11.725 SPS=11553 dt=70.0fs dx=19.11pm
# INFO:root:block  236 pos[1]=[-2.5 1.4 -1.0] dr=0.86 t=1665.4ps kin=1.47 pot=2.02 Rg=11.720 SPS=11355 dt=70.0fs dx=18.95pm
# INFO:root:block  237 pos[1]=[-2.4 2.0 -1.0] dr=0.87 t=1672.4ps kin=1.49 pot=1.99 Rg=11.712 SPS=11727 dt=70.0fs dx=19.12pm
# INFO:root:block  238 pos[1]=[-2.2 2.1 -0.6] dr=0.87 t=1679.4ps kin=1.47 pot=2.02 Rg=11.698 SPS=11350 dt=70.0fs dx=18.95pm
# INFO:root:block  239 pos[1]=[-2.1 2.9 -0.9] dr=0.87 t=1686.4ps kin=1.47 pot=2.01 Rg=11.690 SPS=11040 dt=70.0fs dx=18.99pm
# INFO:root:block  240 pos[1]=[-2.2 3.1 -1.5] dr=0.87 t=1693.4ps kin=1.49 pot=1.99 Rg=11.692 SPS=11369 dt=70.0fs dx=19.11pm
# INFO:root:block  241 pos[1]=[-1.7 3.2 -0.4] dr=0.86 t=1700.4ps kin=1.47 pot=2.00 Rg=11.693 SPS=11053 dt=70.0fs dx=18.95pm
# INFO:root:block  242 pos[1]=[-2.0 2.9 0.0] dr=0.87 t=1707.4ps kin=1.49 pot=1.98 Rg=11.706 SPS=11338 dt=70.0fs dx=19.09pm
# INFO:root:block  243 pos[1]=[-2.7 2.8 0.6] dr=0.87 t=1714.4ps kin=1.48 pot=1.99 Rg=11.726 SPS=11454 dt=70.0fs dx=19.02pm
# INFO:root:block  244 pos[1]=[-3.0 2.2 0.5] dr=0.87 t=1721.4ps kin=1.47 pot=1.99 Rg=11.727 SPS=11089 dt=70.0fs dx=18.97pm
# INFO:root:block  245 pos[1]=[-2.3 2.0 -0.2] dr=0.87 t=1728.4ps kin=1.48 pot=2.00 Rg=11.710 SPS=11643 dt=70.0fs dx=19.00pm
# INFO:root:block  246 pos[1]=[-2.5 2.1 -0.6] dr=0.86 t=1735.4ps kin=1.49 pot=1.99 Rg=11.694 SPS=11150 dt=70.0fs dx=19.07pm
# INFO:root:block  247 pos[1]=[-2.5 1.8 -0.7] dr=0.86 t=1742.5ps kin=1.48 pot=1.99 Rg=11.680 SPS=11359 dt=70.0fs dx=19.04pm
# INFO:root:block  248 pos[1]=[-2.1 2.4 -0.8] dr=0.86 t=1749.5ps kin=1.48 pot=1.99 Rg=11.683 SPS=11464 dt=70.0fs dx=19.01pm
# INFO:root:block  249 pos[1]=[-2.4 1.7 -1.1] dr=0.86 t=1756.5ps kin=1.47 pot=1.99 Rg=11.678 SPS=11234 dt=70.0fs dx=18.94pm
# INFO:root:block  250 pos[1]=[-2.6 2.0 -1.2] dr=0.86 t=1763.5ps kin=1.47 pot=1.99 Rg=11.682 SPS=11315 dt=70.0fs dx=18.99pm
# INFO:root:block  251 pos[1]=[-2.8 0.9 -0.8] dr=0.87 t=1770.5ps kin=1.47 pot=2.00 Rg=11.696 SPS=11467 dt=70.0fs dx=18.98pm
# INFO:root:block  252 pos[1]=[-2.1 0.5 -0.9] dr=0.87 t=1777.5ps kin=1.47 pot=1.99 Rg=11.714 SPS=11216 dt=70.0fs dx=18.94pm
# INFO:root:block  253 pos[1]=[-2.1 1.1 -1.1] dr=0.86 t=1784.5ps kin=1.48 pot=1.98 Rg=11.716 SPS=11328 dt=70.0fs dx=19.02pm
# INFO:root:block  254 pos[1]=[-2.9 1.2 -1.9] dr=0.87 t=1791.5ps kin=1.46 pot=2.00 Rg=11.707 SPS=11233 dt=70.0fs dx=18.93pm
# INFO:root:block  255 pos[1]=[-3.3 0.6 -2.9] dr=0.87 t=1798.5ps kin=1.50 pot=1.97 Rg=11.693 SPS=11504 dt=70.0fs dx=19.15pm
# INFO:root:block  256 pos[1]=[-2.3 0.6 -2.4] dr=0.88 t=1805.5ps kin=1.47 pot=1.98 Rg=11.676 SPS=11531 dt=70.0fs dx=18.94pm
# INFO:root:block  257 pos[1]=[-1.4 -0.1 -3.1] dr=0.86 t=1812.5ps kin=1.47 pot=1.97 Rg=11.666 SPS=11153 dt=70.0fs dx=18.96pm
# INFO:root:block  258 pos[1]=[-2.6 1.1 -3.9] dr=0.87 t=1819.5ps kin=1.45 pot=1.99 Rg=11.658 SPS=11445 dt=70.0fs dx=18.82pm
# INFO:root:block  259 pos[1]=[-2.6 1.5 -4.0] dr=0.86 t=1826.5ps kin=1.47 pot=1.98 Rg=11.666 SPS=11249 dt=70.0fs dx=18.97pm
# INFO:root:block  260 pos[1]=[-2.5 1.6 -3.0] dr=0.86 t=1833.5ps kin=1.46 pot=1.99 Rg=11.685 SPS=11360 dt=70.0fs dx=18.93pm
# INFO:root:block  261 pos[1]=[-3.3 1.6 -3.7] dr=0.86 t=1840.5ps kin=1.47 pot=1.97 Rg=11.701 SPS=11445 dt=70.0fs dx=18.96pm
# INFO:root:block  262 pos[1]=[-3.1 0.6 -4.7] dr=0.86 t=1847.5ps kin=1.47 pot=1.98 Rg=11.696 SPS=11260 dt=70.0fs dx=18.99pm
# INFO:root:block  263 pos[1]=[-2.5 0.7 -4.3] dr=0.87 t=1854.5ps kin=1.48 pot=1.97 Rg=11.697 SPS=11236 dt=70.0fs dx=19.01pm
# INFO:root:block  264 pos[1]=[-3.0 -0.3 -3.9] dr=0.87 t=1861.5ps kin=1.46 pot=1.98 Rg=11.699 SPS=11296 dt=70.0fs dx=18.91pm
# INFO:root:block  265 pos[1]=[-2.3 -1.4 -5.3] dr=0.87 t=1868.5ps kin=1.47 pot=1.97 Rg=11.706 SPS=11327 dt=70.0fs dx=18.97pm
# INFO:root:block  266 pos[1]=[-2.1 -0.8 -4.7] dr=0.86 t=1875.5ps kin=1.47 pot=1.96 Rg=11.711 SPS=11538 dt=70.0fs dx=18.96pm
# INFO:root:block  267 pos[1]=[-2.2 -0.3 -5.3] dr=0.86 t=1882.5ps kin=1.47 pot=1.97 Rg=11.715 SPS=11092 dt=70.0fs dx=18.94pm
# INFO:root:block  268 pos[1]=[-2.2 -1.4 -4.9] dr=0.87 t=1889.5ps kin=1.45 pot=1.99 Rg=11.714 SPS=11300 dt=70.0fs dx=18.84pm
# INFO:root:block  269 pos[1]=[-2.3 -1.4 -4.8] dr=0.86 t=1896.5ps kin=1.47 pot=1.98 Rg=11.706 SPS=11104 dt=70.0fs dx=18.95pm
# INFO:root:block  270 pos[1]=[-2.2 -1.7 -5.0] dr=0.87 t=1903.5ps kin=1.48 pot=1.97 Rg=11.694 SPS=11468 dt=70.0fs dx=19.05pm
# INFO:root:block  271 pos[1]=[-1.1 -1.4 -4.0] dr=0.88 t=1910.5ps kin=1.47 pot=1.98 Rg=11.695 SPS=11375 dt=70.0fs dx=18.97pm
# INFO:root:block  272 pos[1]=[-1.1 -2.3 -3.9] dr=0.86 t=1917.5ps kin=1.47 pot=1.98 Rg=11.702 SPS=11153 dt=70.0fs dx=18.98pm
# INFO:root:block  273 pos[1]=[-1.4 -1.8 -4.2] dr=0.86 t=1924.5ps kin=1.49 pot=1.99 Rg=11.710 SPS=11669 dt=70.0fs dx=19.10pm
# INFO:root:block  274 pos[1]=[-1.6 -1.6 -4.2] dr=0.88 t=1931.5ps kin=1.48 pot=2.01 Rg=11.711 SPS=11569 dt=70.0fs dx=19.04pm
# INFO:root:block  275 pos[1]=[-1.4 -1.5 -4.0] dr=0.86 t=1938.5ps kin=1.47 pot=2.01 Rg=11.700 SPS=11111 dt=70.0fs dx=18.97pm
# INFO:root:block  276 pos[1]=[-1.3 -1.3 -4.1] dr=0.86 t=1945.5ps kin=1.48 pot=1.98 Rg=11.694 SPS=11315 dt=70.0fs dx=19.03pm
# INFO:root:block  277 pos[1]=[-1.3 -0.6 -4.8] dr=0.87 t=1952.5ps kin=1.47 pot=1.99 Rg=11.684 SPS=11067 dt=70.0fs dx=18.97pm
# INFO:root:block  278 pos[1]=[-1.2 0.2 -4.3] dr=0.86 t=1959.5ps kin=1.46 pot=1.99 Rg=11.679 SPS=11370 dt=70.0fs dx=18.90pm
# INFO:root:block  279 pos[1]=[-0.4 0.3 -4.1] dr=0.86 t=1966.5ps kin=1.48 pot=1.99 Rg=11.691 SPS=10924 dt=70.0fs dx=19.04pm
# INFO:root:block  280 pos[1]=[-0.2 0.5 -4.3] dr=0.87 t=1973.5ps kin=1.47 pot=2.01 Rg=11.704 SPS=11383 dt=70.0fs dx=18.96pm
# INFO:root:block  281 pos[1]=[1.0 0.6 -4.2] dr=0.88 t=1980.5ps kin=1.49 pot=1.97 Rg=11.720 SPS=11504 dt=70.0fs dx=19.12pm
# INFO:root:block  282 pos[1]=[0.3 1.4 -5.0] dr=0.87 t=1987.5ps kin=1.46 pot=1.99 Rg=11.728 SPS=11155 dt=70.0fs dx=18.90pm
# INFO:root:block  283 pos[1]=[0.9 1.7 -4.6] dr=0.87 t=1994.5ps kin=1.49 pot=1.98 Rg=11.724 SPS=11478 dt=70.0fs dx=19.06pm
# INFO:root:block  284 pos[1]=[1.0 1.4 -5.1] dr=0.86 t=2001.5ps kin=1.46 pot=2.01 Rg=11.725 SPS=11070 dt=70.0fs dx=18.87pm
# INFO:root:block  285 pos[1]=[-0.9 1.2 -4.3] dr=0.86 t=2008.5ps kin=1.46 pot=1.99 Rg=11.722 SPS=11368 dt=70.0fs dx=18.93pm
# INFO:root:block  286 pos[1]=[-1.6 0.8 -3.8] dr=0.87 t=2015.6ps kin=1.47 pot=1.97 Rg=11.728 SPS=11245 dt=70.0fs dx=18.95pm
# INFO:root:block  287 pos[1]=[-1.4 0.3 -4.7] dr=0.87 t=2022.6ps kin=1.47 pot=1.97 Rg=11.728 SPS=11353 dt=70.0fs dx=18.99pm
# INFO:root:block  288 pos[1]=[-0.6 -0.1 -5.4] dr=0.87 t=2029.6ps kin=1.46 pot=1.99 Rg=11.729 SPS=11568 dt=70.0fs dx=18.90pm
# INFO:root:block  289 pos[1]=[-0.8 0.3 -5.5] dr=0.86 t=2036.6ps kin=1.46 pot=2.00 Rg=11.723 SPS=11340 dt=70.0fs dx=18.91pm
# INFO:root:block  290 pos[1]=[-0.9 -0.3 -5.4] dr=0.86 t=2043.6ps kin=1.47 pot=1.98 Rg=11.712 SPS=11445 dt=70.0fs dx=18.96pm
# INFO:root:block  291 pos[1]=[-0.7 -0.8 -5.7] dr=0.87 t=2050.6ps kin=1.46 pot=2.00 Rg=11.698 SPS=11250 dt=70.0fs dx=18.88pm
# INFO:root:block  292 pos[1]=[-0.1 -0.9 -5.6] dr=0.87 t=2057.6ps kin=1.49 pot=1.98 Rg=11.691 SPS=11031 dt=70.0fs dx=19.06pm
# INFO:root:block  293 pos[1]=[0.2 -1.2 -4.8] dr=0.87 t=2064.6ps kin=1.49 pot=1.99 Rg=11.683 SPS=11304 dt=70.0fs dx=19.07pm
# INFO:root:block  294 pos[1]=[-0.4 -1.0 -4.9] dr=0.86 t=2071.6ps kin=1.46 pot=2.01 Rg=11.681 SPS=11251 dt=70.0fs dx=18.91pm
# INFO:root:block  295 pos[1]=[-0.0 -0.1 -5.4] dr=0.86 t=2078.6ps kin=1.45 pot=2.00 Rg=11.684 SPS=11442 dt=70.0fs dx=18.86pm
# INFO:root:block  296 pos[1]=[-0.7 1.3 -5.8] dr=0.86 t=2085.6ps kin=1.48 pot=1.98 Rg=11.690 SPS=11251 dt=70.0fs dx=19.00pm
# INFO:root:block  297 pos[1]=[0.4 0.5 -5.8] dr=0.85 t=2092.6ps kin=1.47 pot=1.99 Rg=11.701 SPS=11241 dt=70.0fs dx=18.99pm
# INFO:root:block  298 pos[1]=[0.4 -0.4 -6.2] dr=0.87 t=2099.6ps kin=1.46 pot=1.99 Rg=11.709 SPS=11132 dt=70.0fs dx=18.92pm
# INFO:root:block  299 pos[1]=[0.5 0.2 -6.1] dr=0.86 t=2106.6ps kin=1.47 pot=2.00 Rg=11.725 SPS=10676 dt=70.0fs dx=18.93pm
# INFO:root:block  300 pos[1]=[0.8 0.7 -6.6] dr=0.86 t=2113.6ps kin=1.48 pot=1.97 Rg=11.726 SPS=11475 dt=70.0fs dx=19.05pm
# INFO:root:block  301 pos[1]=[1.5 0.7 -6.1] dr=0.86 t=2120.6ps kin=1.47 pot=1.99 Rg=11.712 SPS=11352 dt=70.0fs dx=18.99pm
# INFO:root:block  302 pos[1]=[2.2 0.4 -6.6] dr=0.86 t=2127.6ps kin=1.47 pot=1.99 Rg=11.704 SPS=11317 dt=70.0fs dx=18.98pm
# INFO:root:block  303 pos[1]=[2.0 0.8 -6.3] dr=0.86 t=2134.6ps kin=1.46 pot=2.01 Rg=11.697 SPS=11248 dt=70.0fs dx=18.88pm
# INFO:root:block  304 pos[1]=[2.0 1.6 -6.5] dr=0.87 t=2141.6ps kin=1.49 pot=1.97 Rg=11.698 SPS=10982 dt=70.0fs dx=19.09pm
# INFO:root:block  305 pos[1]=[2.3 2.2 -6.3] dr=0.86 t=2148.6ps kin=1.48 pot=1.98 Rg=11.695 SPS=11268 dt=70.0fs dx=19.01pm
# INFO:root:block  306 pos[1]=[2.4 2.2 -6.3] dr=0.87 t=2155.6ps kin=1.47 pot=2.00 Rg=11.688 SPS=11443 dt=70.0fs dx=18.96pm
# INFO:root:block  307 pos[1]=[2.0 0.8 -6.3] dr=0.87 t=2162.6ps kin=1.47 pot=1.99 Rg=11.682 SPS=11045 dt=70.0fs dx=18.96pm
# INFO:root:block  308 pos[1]=[2.2 -0.1 -6.4] dr=0.86 t=2169.6ps kin=1.48 pot=1.99 Rg=11.684 SPS=11336 dt=70.0fs dx=19.05pm
# INFO:root:block  309 pos[1]=[2.1 -0.2 -6.3] dr=0.87 t=2176.6ps kin=1.50 pot=1.98 Rg=11.687 SPS=11046 dt=70.0fs dx=19.13pm
# INFO:root:block  310 pos[1]=[2.3 0.3 -6.5] dr=0.87 t=2183.6ps kin=1.49 pot=2.00 Rg=11.697 SPS=11513 dt=70.0fs dx=19.08pm
# INFO:root:block  311 pos[1]=[2.0 0.2 -7.1] dr=0.87 t=2190.6ps kin=1.47 pot=2.01 Rg=11.709 SPS=11550 dt=70.0fs dx=18.99pm
# INFO:root:block  312 pos[1]=[1.8 -0.6 -7.5] dr=0.87 t=2197.6ps kin=1.49 pot=1.99 Rg=11.712 SPS=11282 dt=70.0fs dx=19.10pm
# INFO:root:block  313 pos[1]=[2.2 -1.2 -7.7] dr=0.88 t=2204.6ps kin=1.47 pot=2.00 Rg=11.714 SPS=11423 dt=70.0fs dx=18.99pm
# INFO:root:block  314 pos[1]=[2.0 -1.1 -7.9] dr=0.87 t=2211.6ps kin=1.48 pot=1.99 Rg=11.705 SPS=11020 dt=70.0fs dx=19.02pm
# INFO:root:block  315 pos[1]=[0.3 -1.4 -7.4] dr=0.88 t=2218.6ps kin=1.49 pot=2.00 Rg=11.697 SPS=11267 dt=70.0fs dx=19.10pm
# INFO:root:block  316 pos[1]=[1.5 -1.4 -7.7] dr=0.87 t=2225.6ps kin=1.49 pot=2.01 Rg=11.683 SPS=11319 dt=70.0fs dx=19.08pm
# INFO:root:block  317 pos[1]=[1.3 -1.0 -8.1] dr=0.87 t=2232.6ps kin=1.49 pot=2.00 Rg=11.675 SPS=10929 dt=70.0fs dx=19.12pm
# INFO:root:block  318 pos[1]=[1.5 -2.1 -7.1] dr=0.88 t=2239.6ps kin=1.48 pot=2.01 Rg=11.676 SPS=11362 dt=70.0fs dx=19.00pm
# INFO:root:block  319 pos[1]=[1.2 -1.9 -6.3] dr=0.87 t=2246.6ps kin=1.49 pot=2.01 Rg=11.681 SPS=11256 dt=70.0fs dx=19.11pm
# INFO:root:block  320 pos[1]=[0.5 -2.8 -7.1] dr=0.87 t=2253.6ps kin=1.48 pot=2.00 Rg=11.677 SPS=11396 dt=70.0fs dx=19.03pm
# INFO:root:block  321 pos[1]=[0.4 -2.3 -6.7] dr=0.86 t=2260.6ps kin=1.47 pot=2.01 Rg=11.678 SPS=11341 dt=70.0fs dx=18.93pm
# INFO:root:block  322 pos[1]=[-0.4 -1.9 -7.0] dr=0.86 t=2267.6ps kin=1.48 pot=1.99 Rg=11.688 SPS=11105 dt=70.0fs dx=19.02pm
# INFO:root:block  323 pos[1]=[-0.3 -1.8 -6.4] dr=0.86 t=2274.6ps kin=1.47 pot=1.98 Rg=11.696 SPS=11318 dt=70.0fs dx=18.95pm
# INFO:root:block  324 pos[1]=[-0.5 -2.5 -7.3] dr=0.85 t=2281.7ps kin=1.47 pot=2.00 Rg=11.704 SPS=10986 dt=70.0fs dx=18.97pm
# INFO:root:block  325 pos[1]=[-0.1 -1.7 -8.3] dr=0.86 t=2288.7ps kin=1.48 pot=1.99 Rg=11.701 SPS=11462 dt=70.0fs dx=19.01pm
# INFO:root:block  326 pos[1]=[-0.1 -1.5 -9.1] dr=0.86 t=2295.7ps kin=1.49 pot=2.00 Rg=11.704 SPS=11294 dt=70.0fs dx=19.06pm
# INFO:root:block  327 pos[1]=[0.3 -1.5 -8.9] dr=0.87 t=2302.7ps kin=1.47 pot=2.02 Rg=11.700 SPS=10955 dt=70.0fs dx=18.95pm
# INFO:root:block  328 pos[1]=[0.4 -1.5 -8.0] dr=0.86 t=2309.7ps kin=1.49 pot=2.03 Rg=11.693 SPS=11471 dt=70.0fs dx=19.08pm
# INFO:root:block  329 pos[1]=[0.1 -0.8 -8.4] dr=0.87 t=2316.7ps kin=1.50 pot=2.01 Rg=11.693 SPS=11039 dt=70.0fs dx=19.16pm
# INFO:root:block  330 pos[1]=[1.2 -0.4 -9.0] dr=0.87 t=2323.7ps kin=1.50 pot=2.00 Rg=11.690 SPS=11369 dt=70.0fs dx=19.14pm
# INFO:root:block  331 pos[1]=[1.2 -0.3 -9.0] dr=0.86 t=2330.7ps kin=1.46 pot=2.00 Rg=11.688 SPS=11378 dt=70.0fs dx=18.92pm
# INFO:root:block  332 pos[1]=[2.0 -0.6 -8.8] dr=0.86 t=2337.7ps kin=1.47 pot=1.99 Rg=11.681 SPS=11115 dt=70.0fs dx=18.99pm
# INFO:root:block  333 pos[1]=[1.5 -1.0 -8.7] dr=0.85 t=2344.7ps kin=1.46 pot=1.98 Rg=11.678 SPS=11477 dt=70.0fs dx=18.88pm
# INFO:root:block  334 pos[1]=[1.3 -2.0 -9.5] dr=0.86 t=2351.7ps kin=1.47 pot=1.97 Rg=11.679 SPS=11248 dt=70.0fs dx=18.96pm
# INFO:root:block  335 pos[1]=[1.6 -2.8 -9.1] dr=0.86 t=2358.7ps kin=1.47 pot=1.98 Rg=11.691 SPS=11477 dt=70.0fs dx=18.98pm
# INFO:root:block  336 pos[1]=[1.2 -2.3 -10.0] dr=0.86 t=2365.7ps kin=1.48 pot=1.98 Rg=11.705 SPS=11361 dt=70.0fs dx=19.01pm
# INFO:root:block  337 pos[1]=[1.4 -2.1 -9.4] dr=0.86 t=2372.7ps kin=1.47 pot=1.97 Rg=11.716 SPS=11140 dt=70.0fs dx=18.94pm
# INFO:root:block  338 pos[1]=[0.3 -1.5 -9.1] dr=0.86 t=2379.7ps kin=1.47 pot=1.97 Rg=11.725 SPS=11401 dt=70.0fs dx=18.98pm
# INFO:root:block  339 pos[1]=[0.7 -1.1 -8.6] dr=0.86 t=2386.7ps kin=1.47 pot=1.97 Rg=11.715 SPS=11228 dt=70.0fs dx=18.95pm
# INFO:root:block  340 pos[1]=[0.0 -2.7 -8.8] dr=0.86 t=2393.7ps kin=1.45 pot=2.01 Rg=11.702 SPS=11349 dt=70.0fs dx=18.86pm
# INFO:root:block  341 pos[1]=[0.5 -3.1 -8.2] dr=0.87 t=2400.7ps kin=1.50 pot=1.97 Rg=11.691 SPS=11476 dt=70.0fs dx=19.13pm
# INFO:root:block  342 pos[1]=[0.4 -2.0 -7.7] dr=0.87 t=2407.7ps kin=1.48 pot=1.98 Rg=11.687 SPS=11118 dt=70.0fs dx=19.05pm
# INFO:root:block  343 pos[1]=[-0.1 -1.6 -7.2] dr=0.87 t=2414.7ps kin=1.48 pot=1.99 Rg=11.685 SPS=11174 dt=70.0fs dx=19.04pm
# INFO:root:block  344 pos[1]=[0.1 -1.8 -7.9] dr=0.87 t=2421.7ps kin=1.48 pot=1.99 Rg=11.684 SPS=11249 dt=70.0fs dx=19.04pm
# INFO:root:block  345 pos[1]=[0.9 -2.1 -8.2] dr=0.88 t=2428.7ps kin=1.47 pot=2.00 Rg=11.689 SPS=11349 dt=70.0fs dx=19.00pm
# INFO:root:block  346 pos[1]=[0.9 -2.6 -8.1] dr=0.86 t=2435.7ps kin=1.47 pot=2.01 Rg=11.695 SPS=11486 dt=70.0fs dx=18.96pm
# INFO:root:block  347 pos[1]=[0.3 -2.9 -7.3] dr=0.87 t=2442.7ps kin=1.46 pot=2.00 Rg=11.684 SPS=11094 dt=70.0fs dx=18.92pm
# INFO:root:block  348 pos[1]=[0.6 -2.9 -8.2] dr=0.87 t=2449.7ps kin=1.46 pot=1.99 Rg=11.679 SPS=11473 dt=70.0fs dx=18.93pm
# INFO:root:block  349 pos[1]=[0.9 -2.9 -8.1] dr=0.86 t=2456.7ps kin=1.46 pot=1.99 Rg=11.670 SPS=11099 dt=70.0fs dx=18.93pm
# INFO:root:block  350 pos[1]=[0.7 -2.4 -8.8] dr=0.86 t=2463.7ps kin=1.47 pot=2.00 Rg=11.674 SPS=11324 dt=70.0fs dx=18.95pm
# INFO:root:block  351 pos[1]=[0.6 -2.0 -10.2] dr=0.86 t=2470.7ps kin=1.45 pot=1.99 Rg=11.680 SPS=11443 dt=70.0fs dx=18.83pm
# INFO:root:block  352 pos[1]=[1.1 -2.9 -9.5] dr=0.86 t=2477.7ps kin=1.47 pot=1.97 Rg=11.690 SPS=10985 dt=70.0fs dx=18.95pm
# INFO:root:block  353 pos[1]=[1.3 -1.9 -9.7] dr=0.87 t=2484.7ps kin=1.48 pot=1.96 Rg=11.712 SPS=11469 dt=70.0fs dx=19.01pm
# INFO:root:block  354 pos[1]=[1.5 -1.9 -9.9] dr=0.87 t=2491.7ps kin=1.47 pot=1.96 Rg=11.714 SPS=11232 dt=70.0fs dx=18.97pm
# INFO:root:block  355 pos[1]=[2.0 -1.0 -9.2] dr=0.86 t=2498.7ps kin=1.45 pot=1.98 Rg=11.708 SPS=11244 dt=70.0fs dx=18.83pm
# INFO:root:block  356 pos[1]=[2.1 -0.4 -9.4] dr=0.86 t=2505.7ps kin=1.46 pot=1.97 Rg=11.698 SPS=11341 dt=70.0fs dx=18.92pm
# INFO:root:block  357 pos[1]=[1.7 0.3 -9.5] dr=0.86 t=2512.7ps kin=1.46 pot=1.98 Rg=11.690 SPS=11245 dt=70.0fs dx=18.88pm
# INFO:root:block  358 pos[1]=[1.9 1.2 -8.9] dr=0.86 t=2519.7ps kin=1.46 pot=1.99 Rg=11.703 SPS=11314 dt=70.0fs dx=18.92pm
# INFO:root:block  359 pos[1]=[2.0 1.3 -9.6] dr=0.87 t=2526.7ps kin=1.48 pot=1.98 Rg=11.709 SPS=11116 dt=70.0fs dx=19.03pm
# INFO:root:block  360 pos[1]=[1.5 0.7 -9.9] dr=0.86 t=2533.7ps kin=1.48 pot=1.98 Rg=11.703 SPS=11355 dt=70.0fs dx=19.03pm
# INFO:root:block  361 pos[1]=[2.3 1.1 -9.2] dr=0.86 t=2540.7ps kin=1.47 pot=1.98 Rg=11.695 SPS=11233 dt=70.0fs dx=18.95pm
# INFO:root:block  362 pos[1]=[2.5 0.9 -9.6] dr=0.86 t=2547.7ps kin=1.48 pot=1.97 Rg=11.677 SPS=10966 dt=70.0fs dx=19.02pm
# INFO:root:block  363 pos[1]=[2.7 -0.7 -8.9] dr=0.86 t=2554.8ps kin=1.47 pot=1.97 Rg=11.673 SPS=11299 dt=70.0fs dx=18.96pm
# INFO:root:block  364 pos[1]=[2.8 -0.3 -9.5] dr=0.86 t=2561.8ps kin=1.49 pot=1.97 Rg=11.679 SPS=11128 dt=70.0fs dx=19.08pm
# INFO:root:block  365 pos[1]=[2.6 -0.5 -9.9] dr=0.87 t=2568.8ps kin=1.47 pot=1.99 Rg=11.688 SPS=11338 dt=70.0fs dx=18.95pm
# INFO:root:block  366 pos[1]=[2.7 -0.1 -10.1] dr=0.87 t=2575.8ps kin=1.46 pot=2.01 Rg=11.693 SPS=11411 dt=70.0fs dx=18.87pm
# INFO:root:block  367 pos[1]=[2.8 -0.5 -10.2] dr=0.87 t=2582.8ps kin=1.47 pot=1.97 Rg=11.688 SPS=11142 dt=70.0fs dx=18.98pm
# INFO:root:block  368 pos[1]=[2.3 -0.2 -9.4] dr=0.86 t=2589.8ps kin=1.47 pot=1.98 Rg=11.690 SPS=11425 dt=70.0fs dx=18.95pm
# INFO:root:block  369 pos[1]=[2.1 -1.2 -8.9] dr=0.86 t=2596.8ps kin=1.47 pot=2.00 Rg=11.688 SPS=11240 dt=70.0fs dx=18.96pm
# INFO:root:block  370 pos[1]=[2.2 -1.3 -9.7] dr=0.86 t=2603.8ps kin=1.48 pot=1.99 Rg=11.700 SPS=11221 dt=70.0fs dx=19.00pm
# INFO:root:block  371 pos[1]=[1.9 -1.6 -9.5] dr=0.86 t=2610.8ps kin=1.47 pot=2.00 Rg=11.712 SPS=11500 dt=70.0fs dx=18.99pm
# INFO:root:block  372 pos[1]=[2.3 -1.0 -9.9] dr=0.86 t=2617.8ps kin=1.48 pot=2.00 Rg=11.712 SPS=11105 dt=70.0fs dx=19.03pm
# INFO:root:block  373 pos[1]=[2.1 -0.4 -11.1] dr=0.87 t=2624.8ps kin=1.49 pot=1.99 Rg=11.712 SPS=11306 dt=70.0fs dx=19.10pm
# INFO:root:block  374 pos[1]=[2.4 -0.7 -10.9] dr=0.86 t=2631.8ps kin=1.47 pot=2.01 Rg=11.700 SPS=11414 dt=70.0fs dx=18.93pm
# INFO:root:block  375 pos[1]=[2.3 -0.4 -9.8] dr=0.87 t=2638.8ps kin=1.47 pot=2.01 Rg=11.682 SPS=11167 dt=70.0fs dx=18.96pm
# INFO:root:block  376 pos[1]=[1.7 -0.3 -10.2] dr=0.87 t=2645.8ps kin=1.49 pot=1.98 Rg=11.668 SPS=11334 dt=70.0fs dx=19.12pm
# INFO:root:block  377 pos[1]=[2.4 0.3 -9.1] dr=0.85 t=2652.8ps kin=1.48 pot=1.98 Rg=11.671 SPS=11000 dt=70.0fs dx=19.05pm
# INFO:root:block  378 pos[1]=[2.4 0.4 -9.5] dr=0.86 t=2659.8ps kin=1.48 pot=1.98 Rg=11.683 SPS=11189 dt=70.0fs dx=19.05pm
# INFO:root:block  379 pos[1]=[2.0 0.8 -9.4] dr=0.86 t=2666.8ps kin=1.49 pot=1.97 Rg=11.687 SPS=11360 dt=70.0fs dx=19.11pm
# INFO:root:block  380 pos[1]=[1.2 0.8 -9.7] dr=0.86 t=2673.8ps kin=1.48 pot=1.99 Rg=11.693 SPS=11099 dt=70.0fs dx=19.00pm
# INFO:root:block  381 pos[1]=[0.5 0.7 -9.7] dr=0.88 t=2680.8ps kin=1.47 pot=2.01 Rg=11.699 SPS=11279 dt=70.0fs dx=18.96pm
# INFO:root:block  382 pos[1]=[-0.7 0.4 -9.1] dr=0.88 t=2687.8ps kin=1.48 pot=1.98 Rg=11.706 SPS=11019 dt=70.0fs dx=19.01pm
# INFO:root:block  383 pos[1]=[-1.2 0.2 -8.2] dr=0.87 t=2694.8ps kin=1.47 pot=1.98 Rg=11.700 SPS=11367 dt=70.0fs dx=18.99pm
# INFO:root:block  384 pos[1]=[-0.5 1.2 -7.6] dr=0.87 t=2701.8ps kin=1.47 pot=1.99 Rg=11.696 SPS=11369 dt=70.0fs dx=18.99pm
# INFO:root:block  385 pos[1]=[-0.5 1.7 -7.4] dr=0.87 t=2708.8ps kin=1.49 pot=1.98 Rg=11.697 SPS=11154 dt=70.0fs dx=19.08pm
# INFO:root:block  386 pos[1]=[-0.5 1.6 -7.1] dr=0.87 t=2715.8ps kin=1.49 pot=1.98 Rg=11.700 SPS=11414 dt=70.0fs dx=19.07pm
# INFO:root:block  387 pos[1]=[-0.8 1.7 -6.9] dr=0.86 t=2722.8ps kin=1.49 pot=1.98 Rg=11.691 SPS=11216 dt=70.0fs dx=19.07pm
# INFO:root:block  388 pos[1]=[-0.8 0.4 -6.4] dr=0.86 t=2729.8ps kin=1.48 pot=2.00 Rg=11.688 SPS=11398 dt=70.0fs dx=19.04pm
# INFO:root:block  389 pos[1]=[-1.0 0.0 -6.6] dr=0.86 t=2736.8ps kin=1.49 pot=1.99 Rg=11.697 SPS=11320 dt=70.0fs dx=19.08pm
# INFO:root:block  390 pos[1]=[-1.4 0.1 -6.7] dr=0.87 t=2743.8ps kin=1.50 pot=1.99 Rg=11.710 SPS=11223 dt=70.0fs dx=19.17pm
# INFO:root:block  391 pos[1]=[-1.7 -0.2 -8.0] dr=0.86 t=2750.8ps kin=1.48 pot=1.99 Rg=11.708 SPS=11193 dt=70.0fs dx=19.04pm
# ...
# INFO:root:block  879 pos[1]=[1.1 1.3 -7.0] dr=0.86 t=6168.1ps kin=1.47 pot=1.98 Rg=11.692 SPS=11140 dt=70.0fs dx=18.96pm
# INFO:root:block  880 pos[1]=[1.1 1.3 -6.5] dr=0.86 t=6175.1ps kin=1.46 pot=2.00 Rg=11.702 SPS=11383 dt=70.0fs dx=18.88pm
# INFO:root:block  881 pos[1]=[0.4 0.9 -6.2] dr=0.87 t=6182.1ps kin=1.47 pot=1.99 Rg=11.710 SPS=11066 dt=70.0fs dx=18.98pm
# INFO:root:block  882 pos[1]=[0.3 1.5 -6.2] dr=0.86 t=6189.1ps kin=1.48 pot=1.99 Rg=11.707 SPS=11192 dt=70.0fs dx=19.03pm
# INFO:root:block  883 pos[1]=[0.2 1.3 -5.8] dr=0.88 t=6196.1ps kin=1.49 pot=1.98 Rg=11.699 SPS=11412 dt=70.0fs dx=19.09pm
# INFO:root:block  884 pos[1]=[0.2 0.9 -5.1] dr=0.87 t=6203.1ps kin=1.49 pot=1.99 Rg=11.687 SPS=10593 dt=70.0fs dx=19.07pm
# INFO:root:block  885 pos[1]=[1.0 1.5 -4.9] dr=0.87 t=6210.1ps kin=1.50 pot=1.98 Rg=11.681 SPS=11259 dt=70.0fs dx=19.15pm
# INFO:root:block  886 pos[1]=[1.0 1.5 -4.0] dr=0.88 t=6217.1ps kin=1.51 pot=1.98 Rg=11.675 SPS=11450 dt=70.0fs dx=19.21pm
# INFO:root:block  887 pos[1]=[0.9 3.5 -3.7] dr=0.87 t=6224.1ps kin=1.48 pot=1.99 Rg=11.668 SPS=11135 dt=70.0fs dx=19.05pm
# INFO:root:block  888 pos[1]=[-0.3 3.8 -3.7] dr=0.87 t=6231.1ps kin=1.48 pot=2.00 Rg=11.669 SPS=11168 dt=70.0fs dx=19.01pm
# INFO:root:block  889 pos[1]=[-0.2 3.4 -4.8] dr=0.87 t=6238.1ps kin=1.49 pot=1.98 Rg=11.681 SPS=11184 dt=70.0fs dx=19.12pm
# INFO:root:block  890 pos[1]=[0.3 3.7 -4.5] dr=0.86 t=6245.1ps kin=1.49 pot=1.98 Rg=11.691 SPS=11416 dt=70.0fs dx=19.09pm
# INFO:root:block  891 pos[1]=[-0.1 3.5 -4.2] dr=0.87 t=6252.1ps kin=1.49 pot=1.97 Rg=11.692 SPS=11454 dt=70.0fs dx=19.11pm
# INFO:root:block  892 pos[1]=[-0.0 4.4 -3.8] dr=0.87 t=6259.1ps kin=1.49 pot=2.00 Rg=11.703 SPS=11294 dt=70.0fs dx=19.06pm
# INFO:root:block  893 pos[1]=[1.1 4.4 -4.1] dr=0.87 t=6266.1ps kin=1.48 pot=1.99 Rg=11.722 SPS=11504 dt=70.0fs dx=19.04pm
# INFO:root:block  894 pos[1]=[1.3 4.3 -4.6] dr=0.87 t=6273.1ps kin=1.48 pot=1.98 Rg=11.729 SPS=11244 dt=70.0fs dx=19.05pm
# INFO:root:block  895 pos[1]=[1.0 4.7 -4.1] dr=0.87 t=6280.1ps kin=1.48 pot=1.99 Rg=11.723 SPS=11455 dt=70.0fs dx=19.02pm
# INFO:root:block  896 pos[1]=[1.6 3.3 -3.6] dr=0.86 t=6287.1ps kin=1.48 pot=2.00 Rg=11.703 SPS=11455 dt=70.0fs dx=19.03pm
# INFO:root:block  897 pos[1]=[0.9 3.9 -3.5] dr=0.87 t=6294.1ps kin=1.48 pot=1.99 Rg=11.680 SPS=11159 dt=70.0fs dx=19.01pm
# INFO:root:block  898 pos[1]=[0.5 3.6 -3.0] dr=0.86 t=6301.1ps kin=1.50 pot=1.96 Rg=11.679 SPS=11390 dt=70.0fs dx=19.17pm
# INFO:root:block  899 pos[1]=[0.6 2.8 -3.0] dr=0.86 t=6308.1ps kin=1.47 pot=1.97 Rg=11.679 SPS=11182 dt=70.0fs dx=18.98pm
# INFO:root:block  900 pos[1]=[-0.1 2.8 -2.6] dr=0.87 t=6315.1ps kin=1.47 pot=1.98 Rg=11.667 SPS=11319 dt=70.0fs dx=18.98pm
# INFO:root:block  901 pos[1]=[-0.5 2.1 -2.9] dr=0.86 t=6322.1ps kin=1.46 pot=1.98 Rg=11.662 SPS=11456 dt=70.0fs dx=18.90pm
# INFO:root:block  902 pos[1]=[-0.2 2.7 -3.0] dr=0.87 t=6329.1ps kin=1.47 pot=1.97 Rg=11.657 SPS=11083 dt=70.0fs dx=18.98pm
# INFO:root:block  903 pos[1]=[-0.3 2.4 -2.6] dr=0.86 t=6336.1ps kin=1.47 pot=1.97 Rg=11.668 SPS=11471 dt=70.0fs dx=18.94pm
# INFO:root:block  904 pos[1]=[-0.5 2.4 -1.5] dr=0.86 t=6343.1ps kin=1.45 pot=1.98 Rg=11.683 SPS=11130 dt=70.0fs dx=18.84pm
# INFO:root:block  905 pos[1]=[0.1 2.8 -1.2] dr=0.87 t=6350.2ps kin=1.46 pot=1.98 Rg=11.695 SPS=11256 dt=70.0fs dx=18.88pm
# INFO:root:block  906 pos[1]=[0.0 2.2 -2.9] dr=0.86 t=6357.2ps kin=1.47 pot=1.97 Rg=11.701 SPS=11228 dt=70.0fs dx=18.96pm
# INFO:root:block  907 pos[1]=[-0.1 1.8 -4.1] dr=0.86 t=6364.2ps kin=1.47 pot=1.96 Rg=11.701 SPS=11158 dt=70.0fs dx=18.98pm
# INFO:root:block  908 pos[1]=[-0.1 1.1 -4.2] dr=0.86 t=6371.2ps kin=1.46 pot=1.96 Rg=11.703 SPS=11156 dt=70.0fs dx=18.92pm
# INFO:root:block  909 pos[1]=[-0.5 1.5 -5.1] dr=0.85 t=6378.2ps kin=1.44 pot=1.97 Rg=11.714 SPS=10896 dt=70.0fs dx=18.76pm
# INFO:root:block  910 pos[1]=[-1.0 2.0 -5.5] dr=0.85 t=6385.2ps kin=1.46 pot=1.95 Rg=11.721 SPS=11457 dt=70.0fs dx=18.88pm
# INFO:root:block  911 pos[1]=[-1.4 1.8 -4.7] dr=0.85 t=6392.2ps kin=1.45 pot=1.96 Rg=11.710 SPS=11334 dt=70.0fs dx=18.85pm
# INFO:root:block  912 pos[1]=[-1.3 1.4 -3.8] dr=0.87 t=6399.2ps kin=1.47 pot=1.98 Rg=11.697 SPS=11228 dt=70.0fs dx=18.94pm
# INFO:root:block  913 pos[1]=[-1.3 1.0 -2.6] dr=0.87 t=6406.2ps kin=1.48 pot=1.97 Rg=11.692 SPS=11186 dt=70.0fs dx=19.00pm
# INFO:root:block  914 pos[1]=[-1.6 1.3 -1.3] dr=0.87 t=6413.2ps kin=1.46 pot=1.98 Rg=11.700 SPS=11058 dt=70.0fs dx=18.93pm
# INFO:root:block  915 pos[1]=[-0.5 1.1 -1.6] dr=0.86 t=6420.2ps kin=1.50 pot=1.96 Rg=11.713 SPS=11341 dt=70.0fs dx=19.18pm
# INFO:root:block  916 pos[1]=[-0.3 1.4 -3.0] dr=0.87 t=6427.2ps kin=1.48 pot=1.98 Rg=11.709 SPS=11348 dt=70.0fs dx=19.02pm
# INFO:root:block  917 pos[1]=[1.0 1.3 -2.6] dr=0.86 t=6434.2ps kin=1.48 pot=1.98 Rg=11.691 SPS=11128 dt=70.0fs dx=19.05pm
# INFO:root:block  918 pos[1]=[-0.0 1.6 -2.8] dr=0.86 t=6441.2ps kin=1.46 pot=2.00 Rg=11.684 SPS=11351 dt=70.0fs dx=18.89pm
# INFO:root:block  919 pos[1]=[-0.1 1.1 -3.0] dr=0.86 t=6448.2ps kin=1.48 pot=1.97 Rg=11.688 SPS=11254 dt=70.0fs dx=19.02pm
# INFO:root:block  920 pos[1]=[-0.8 0.8 -2.9] dr=0.86 t=6455.2ps kin=1.48 pot=1.97 Rg=11.688 SPS=11503 dt=70.0fs dx=19.01pm
# INFO:root:block  921 pos[1]=[-1.0 1.8 -3.1] dr=0.86 t=6462.2ps kin=1.47 pot=1.98 Rg=11.686 SPS=11450 dt=70.0fs dx=18.98pm
# INFO:root:block  922 pos[1]=[-0.7 0.8 -3.0] dr=0.87 t=6469.2ps kin=1.47 pot=1.98 Rg=11.688 SPS=11106 dt=70.0fs dx=18.94pm
# INFO:root:block  923 pos[1]=[-0.6 -0.2 -1.8] dr=0.86 t=6476.2ps kin=1.48 pot=1.98 Rg=11.698 SPS=11311 dt=70.0fs dx=19.00pm
# INFO:root:block  924 pos[1]=[-0.9 0.6 -2.2] dr=0.86 t=6483.2ps kin=1.49 pot=1.98 Rg=11.702 SPS=11164 dt=70.0fs dx=19.07pm
# INFO:root:block  925 pos[1]=[-1.6 0.3 -2.5] dr=0.87 t=6490.2ps kin=1.48 pot=2.00 Rg=11.697 SPS=11336 dt=70.0fs dx=19.06pm
# INFO:root:block  926 pos[1]=[-0.2 0.3 -2.9] dr=0.87 t=6497.2ps kin=1.48 pot=1.99 Rg=11.692 SPS=11348 dt=70.0fs dx=19.04pm
# INFO:root:block  927 pos[1]=[-1.2 0.4 -2.8] dr=0.87 t=6504.2ps kin=1.48 pot=2.00 Rg=11.683 SPS=11179 dt=70.0fs dx=19.03pm
# INFO:root:block  928 pos[1]=[-1.8 -0.2 -3.1] dr=0.87 t=6511.2ps kin=1.48 pot=2.00 Rg=11.678 SPS=11312 dt=70.0fs dx=19.06pm
# INFO:root:block  929 pos[1]=[-1.9 -0.5 -2.9] dr=0.87 t=6518.2ps kin=1.48 pot=2.00 Rg=11.685 SPS=11081 dt=70.0fs dx=19.03pm
# INFO:root:block  930 pos[1]=[-2.4 -0.3 -3.1] dr=0.87 t=6525.2ps kin=1.49 pot=2.00 Rg=11.698 SPS=11337 dt=70.0fs dx=19.07pm
# INFO:root:block  931 pos[1]=[-3.3 -0.2 -3.2] dr=0.87 t=6532.2ps kin=1.47 pot=2.00 Rg=11.707 SPS=11290 dt=70.0fs dx=18.99pm
# INFO:root:block  932 pos[1]=[-4.1 -1.0 -3.0] dr=0.87 t=6539.2ps kin=1.49 pot=1.97 Rg=11.715 SPS=11101 dt=70.0fs dx=19.12pm
# INFO:root:block  933 pos[1]=[-3.3 -0.4 -3.6] dr=0.87 t=6546.2ps kin=1.48 pot=1.98 Rg=11.707 SPS=11503 dt=70.0fs dx=19.05pm
# INFO:root:block  934 pos[1]=[-4.6 -1.2 -3.0] dr=0.86 t=6553.2ps kin=1.49 pot=1.98 Rg=11.695 SPS=11083 dt=70.0fs dx=19.10pm
# INFO:root:block  935 pos[1]=[-4.3 -0.6 -0.9] dr=0.87 t=6560.2ps kin=1.48 pot=1.99 Rg=11.687 SPS=11317 dt=70.0fs dx=19.03pm
# INFO:root:block  936 pos[1]=[-3.5 -1.2 -0.2] dr=0.88 t=6567.2ps kin=1.48 pot=1.99 Rg=11.678 SPS=11345 dt=70.0fs dx=19.03pm
# INFO:root:block  937 pos[1]=[-3.1 -1.1 -0.8] dr=0.87 t=6574.2ps kin=1.48 pot=1.99 Rg=11.673 SPS=11115 dt=70.0fs dx=19.04pm
# INFO:root:block  938 pos[1]=[-2.8 -1.2 -1.2] dr=0.86 t=6581.2ps kin=1.48 pot=1.99 Rg=11.682 SPS=11333 dt=70.0fs dx=19.02pm
# INFO:root:block  939 pos[1]=[-3.6 -1.9 -0.9] dr=0.87 t=6588.2ps kin=1.48 pot=2.01 Rg=11.696 SPS=11172 dt=70.0fs dx=19.03pm
# INFO:root:block  940 pos[1]=[-3.2 -2.8 -1.4] dr=0.87 t=6595.2ps kin=1.49 pot=2.00 Rg=11.697 SPS=11465 dt=70.0fs dx=19.09pm
# INFO:root:block  941 pos[1]=[-4.2 -2.0 -0.2] dr=0.87 t=6602.2ps kin=1.50 pot=1.99 Rg=11.700 SPS=11338 dt=70.0fs dx=19.16pm
# INFO:root:block  942 pos[1]=[-5.1 -2.6 0.1] dr=0.87 t=6609.2ps kin=1.48 pot=1.99 Rg=11.698 SPS=11229 dt=70.0fs dx=19.05pm
# INFO:root:block  943 pos[1]=[-6.1 -3.4 -0.2] dr=0.87 t=6616.2ps kin=1.46 pot=2.01 Rg=11.703 SPS=11197 dt=70.0fs dx=18.87pm
# INFO:root:block  944 pos[1]=[-6.7 -2.5 -0.4] dr=0.87 t=6623.3ps kin=1.48 pot=1.99 Rg=11.703 SPS=11051 dt=70.0fs dx=19.04pm
# INFO:root:block  945 pos[1]=[-6.8 -0.5 -1.6] dr=0.86 t=6630.3ps kin=1.49 pot=1.99 Rg=11.697 SPS=11354 dt=70.0fs dx=19.11pm
# INFO:root:block  946 pos[1]=[-6.6 -0.5 -2.0] dr=0.87 t=6637.3ps kin=1.49 pot=2.00 Rg=11.692 SPS=11507 dt=70.0fs dx=19.06pm
# INFO:root:block  947 pos[1]=[-6.2 0.0 -3.0] dr=0.87 t=6644.3ps kin=1.47 pot=1.98 Rg=11.686 SPS=11270 dt=70.0fs dx=18.99pm
# INFO:root:block  948 pos[1]=[-5.9 0.3 -2.8] dr=0.86 t=6651.3ps kin=1.47 pot=1.97 Rg=11.673 SPS=11336 dt=70.0fs dx=18.97pm
# INFO:root:block  949 pos[1]=[-5.1 0.3 -2.8] dr=0.86 t=6658.3ps kin=1.46 pot=1.98 Rg=11.676 SPS=11092 dt=70.0fs dx=18.92pm
# INFO:root:block  950 pos[1]=[-4.7 -0.0 -2.9] dr=0.86 t=6665.3ps kin=1.47 pot=1.97 Rg=11.697 SPS=11449 dt=70.0fs dx=18.96pm
# INFO:root:block  951 pos[1]=[-4.7 -0.3 -3.1] dr=0.86 t=6672.3ps kin=1.48 pot=1.96 Rg=11.706 SPS=11396 dt=70.0fs dx=19.05pm
# INFO:root:block  952 pos[1]=[-4.6 -1.9 -2.4] dr=0.87 t=6679.3ps kin=1.48 pot=1.97 Rg=11.706 SPS=11121 dt=70.0fs dx=19.04pm
# INFO:root:block  953 pos[1]=[-3.2 -3.1 -1.2] dr=0.86 t=6686.3ps kin=1.48 pot=1.99 Rg=11.707 SPS=11483 dt=70.0fs dx=19.00pm
# INFO:root:block  954 pos[1]=[-3.1 -2.6 -1.4] dr=0.86 t=6693.3ps kin=1.48 pot=1.99 Rg=11.719 SPS=11021 dt=70.0fs dx=19.05pm
# INFO:root:block  955 pos[1]=[-2.4 -2.0 -2.2] dr=0.87 t=6700.3ps kin=1.49 pot=1.99 Rg=11.722 SPS=11302 dt=70.0fs dx=19.06pm
# INFO:root:block  956 pos[1]=[-2.3 -1.9 -1.8] dr=0.88 t=6707.3ps kin=1.47 pot=2.00 Rg=11.712 SPS=11406 dt=70.0fs dx=18.98pm
# INFO:root:block  957 pos[1]=[-1.7 -0.9 -2.2] dr=0.87 t=6714.3ps kin=1.47 pot=2.00 Rg=11.697 SPS=11106 dt=70.0fs dx=18.98pm
# INFO:root:block  958 pos[1]=[-1.5 -1.8 -1.7] dr=0.86 t=6721.3ps kin=1.49 pot=1.98 Rg=11.678 SPS=11353 dt=70.0fs dx=19.08pm
# INFO:root:block  959 pos[1]=[-1.5 -1.1 -1.6] dr=0.86 t=6728.3ps kin=1.48 pot=1.98 Rg=11.671 SPS=11193 dt=70.0fs dx=19.05pm
# INFO:root:block  960 pos[1]=[-1.0 -1.5 -1.6] dr=0.86 t=6735.3ps kin=1.48 pot=1.98 Rg=11.683 SPS=11367 dt=70.0fs dx=19.04pm
# INFO:root:block  961 pos[1]=[-0.4 -1.4 -1.7] dr=0.86 t=6742.3ps kin=1.50 pot=1.96 Rg=11.696 SPS=11219 dt=70.0fs dx=19.14pm
# INFO:root:block  962 pos[1]=[-0.8 -1.7 -1.6] dr=0.87 t=6749.3ps kin=1.48 pot=1.98 Rg=11.706 SPS=11105 dt=70.0fs dx=19.01pm
# INFO:root:block  963 pos[1]=[-0.6 -1.6 -2.1] dr=0.86 t=6756.3ps kin=1.49 pot=1.97 Rg=11.718 SPS=11405 dt=70.0fs dx=19.08pm
# INFO:root:block  964 pos[1]=[-1.0 -1.2 -1.7] dr=0.86 t=6763.3ps kin=1.47 pot=2.00 Rg=11.718 SPS=11104 dt=70.0fs dx=18.96pm
# INFO:root:block  965 pos[1]=[-0.9 -1.0 -1.2] dr=0.85 t=6770.3ps kin=1.47 pot=1.97 Rg=11.711 SPS=11511 dt=70.0fs dx=18.99pm
# INFO:root:block  966 pos[1]=[-0.5 -2.5 -1.0] dr=0.86 t=6777.3ps kin=1.49 pot=1.97 Rg=11.691 SPS=11334 dt=70.0fs dx=19.10pm
# INFO:root:block  967 pos[1]=[-0.9 -3.5 -0.8] dr=0.86 t=6784.3ps kin=1.49 pot=1.98 Rg=11.667 SPS=11016 dt=70.0fs dx=19.07pm
# INFO:root:block  968 pos[1]=[-1.3 -4.5 0.2] dr=0.85 t=6791.3ps kin=1.48 pot=1.99 Rg=11.662 SPS=11120 dt=70.0fs dx=19.03pm
# INFO:root:block  969 pos[1]=[-0.9 -5.0 -0.7] dr=0.87 t=6798.3ps kin=1.49 pot=1.98 Rg=11.678 SPS=10963 dt=70.0fs dx=19.09pm
# INFO:root:block  970 pos[1]=[-1.0 -5.5 0.2] dr=0.86 t=6805.3ps kin=1.47 pot=1.98 Rg=11.695 SPS=11444 dt=70.0fs dx=18.99pm
# INFO:root:block  971 pos[1]=[-0.6 -4.8 0.5] dr=0.86 t=6812.3ps kin=1.48 pot=1.98 Rg=11.708 SPS=11466 dt=70.0fs dx=19.00pm
# INFO:root:block  972 pos[1]=[-0.8 -5.6 0.9] dr=0.87 t=6819.3ps kin=1.46 pot=2.00 Rg=11.717 SPS=11114 dt=70.0fs dx=18.92pm
# INFO:root:block  973 pos[1]=[-0.9 -5.9 1.1] dr=0.86 t=6826.3ps kin=1.47 pot=1.99 Rg=11.720 SPS=11329 dt=70.0fs dx=18.99pm
# INFO:root:block  974 pos[1]=[-0.7 -5.7 0.9] dr=0.86 t=6833.3ps kin=1.46 pot=2.00 Rg=11.706 SPS=10947 dt=70.0fs dx=18.89pm
# INFO:root:block  975 pos[1]=[-2.0 -5.6 0.2] dr=0.87 t=6840.3ps kin=1.47 pot=1.97 Rg=11.686 SPS=11376 dt=70.0fs dx=18.97pm
# INFO:root:block  976 pos[1]=[-3.0 -5.3 -0.8] dr=0.86 t=6847.3ps kin=1.47 pot=1.96 Rg=11.674 SPS=11451 dt=70.0fs dx=18.93pm
# INFO:root:block  977 pos[1]=[-2.8 -5.0 -0.3] dr=0.86 t=6854.3ps kin=1.47 pot=1.98 Rg=11.676 SPS=11258 dt=70.0fs dx=18.98pm
# INFO:root:block  978 pos[1]=[-2.8 -5.0 -1.0] dr=0.86 t=6861.3ps kin=1.46 pot=1.99 Rg=11.684 SPS=11280 dt=70.0fs dx=18.93pm
# INFO:root:block  979 pos[1]=[-2.4 -4.9 -0.4] dr=0.87 t=6868.3ps kin=1.49 pot=1.98 Rg=11.695 SPS=11055 dt=70.0fs dx=19.07pm
# INFO:root:block  980 pos[1]=[-3.0 -4.8 -0.4] dr=0.86 t=6875.3ps kin=1.46 pot=2.00 Rg=11.703 SPS=11256 dt=70.0fs dx=18.92pm
# INFO:root:block  981 pos[1]=[-2.8 -4.8 -0.6] dr=0.86 t=6882.3ps kin=1.47 pot=1.99 Rg=11.710 SPS=11458 dt=70.0fs dx=18.96pm
# INFO:root:block  982 pos[1]=[-2.4 -4.7 -1.1] dr=0.86 t=6889.3ps kin=1.47 pot=2.00 Rg=11.716 SPS=11212 dt=70.0fs dx=18.94pm
# INFO:root:block  983 pos[1]=[-2.1 -5.9 -1.3] dr=0.87 t=6896.4ps kin=1.48 pot=2.00 Rg=11.726 SPS=11391 dt=70.0fs dx=19.04pm
# INFO:root:block  984 pos[1]=[-2.5 -5.8 -2.3] dr=0.86 t=6903.4ps kin=1.48 pot=2.00 Rg=11.718 SPS=11163 dt=70.0fs dx=19.01pm
# INFO:root:block  985 pos[1]=[-2.8 -5.4 -2.0] dr=0.87 t=6910.4ps kin=1.48 pot=1.99 Rg=11.708 SPS=11381 dt=70.0fs dx=19.04pm
# INFO:root:block  986 pos[1]=[-3.3 -5.6 -2.8] dr=0.86 t=6917.4ps kin=1.49 pot=1.98 Rg=11.689 SPS=11442 dt=70.0fs dx=19.09pm
# INFO:root:block  987 pos[1]=[-2.4 -5.9 -3.9] dr=0.86 t=6924.4ps kin=1.48 pot=1.98 Rg=11.676 SPS=11145 dt=70.0fs dx=19.02pm
# INFO:root:block  988 pos[1]=[-2.3 -5.5 -3.9] dr=0.87 t=6931.4ps kin=1.47 pot=1.98 Rg=11.684 SPS=11488 dt=70.0fs dx=18.98pm
# INFO:root:block  989 pos[1]=[-2.0 -5.9 -4.3] dr=0.86 t=6938.4ps kin=1.47 pot=1.98 Rg=11.696 SPS=11260 dt=70.0fs dx=18.97pm
# INFO:root:block  990 pos[1]=[-2.4 -6.5 -3.6] dr=0.86 t=6945.4ps kin=1.47 pot=1.98 Rg=11.703 SPS=11485 dt=70.0fs dx=18.97pm
# INFO:root:block  991 pos[1]=[-1.7 -5.7 -3.3] dr=0.86 t=6952.4ps kin=1.46 pot=2.00 Rg=11.690 SPS=11284 dt=70.0fs dx=18.92pm
# INFO:root:block  992 pos[1]=[-1.2 -5.1 -2.6] dr=0.87 t=6959.4ps kin=1.47 pot=1.98 Rg=11.673 SPS=11217 dt=70.0fs dx=18.96pm
# INFO:root:block  993 pos[1]=[-0.4 -4.9 -3.6] dr=0.86 t=6966.4ps kin=1.47 pot=1.97 Rg=11.661 SPS=11418 dt=70.0fs dx=18.97pm
# INFO:root:block  994 pos[1]=[-0.8 -5.5 -4.1] dr=0.86 t=6973.4ps kin=1.47 pot=1.97 Rg=11.654 SPS=11135 dt=70.0fs dx=18.99pm
# INFO:root:block  995 pos[1]=[-0.7 -6.1 -4.2] dr=0.87 t=6980.4ps kin=1.48 pot=1.97 Rg=11.671 SPS=11330 dt=70.0fs dx=19.05pm
# INFO:root:block  996 pos[1]=[-0.2 -5.6 -3.8] dr=0.87 t=6987.4ps kin=1.48 pot=1.97 Rg=11.690 SPS=11373 dt=70.0fs dx=19.00pm
# INFO:root:block  997 pos[1]=[0.2 -5.1 -3.7] dr=0.87 t=6994.4ps kin=1.49 pot=1.99 Rg=11.700 SPS=11166 dt=70.0fs dx=19.07pm
# INFO:root:block  998 pos[1]=[-1.1 -4.8 -4.3] dr=0.87 t=7001.4ps kin=1.49 pot=1.97 Rg=11.701 SPS=11532 dt=70.0fs dx=19.08pm
# INFO:root:block  999 pos[1]=[-1.9 -5.8 -4.0] dr=0.87 t=7008.4ps kin=1.47 pot=2.00 Rg=11.695 SPS=11147 dt=70.0fs dx=18.95pm
#  Statistics: number of particles: 10000
#
# Statistics for particle position
#      mean position is:  [-0.00695531  0.00026535 -0.01560917]   Rg =  11.694612
#      median bond size is  1.0007475828031211
#      three shortest/longest (<10)/ bonds are  [0.85884782 0.85917534 0.86391248]    [1.11316676 1.1249872  1.13418871]
#      95 percentile of distance to center is:    15.103458515249397
#      density of closest 95% monomers is:    0.6582725947354539
#      density of the 5% closest to CoM monomers is:    0.7077897008513381
#      min/median/mean/max coordinates are:
#      x: -15.69, -0.01, -0.01, 15.73
#      y: -16.18, -0.02, 0.00, 15.87
#      z: -15.52, 0.03, -0.02, 14.96
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4927967306011463 should be: 1.5
#      fastest particles are (in kT):  [ 9.15507764  9.39670537  9.46568817  9.68375988 11.42458175]
#
# Statistics for the system:
#      Forces are:  ['spherical_confinement', 'harmonic_bonds', 'angle', 'polynomial_repulsive']
#
# Potential Energy Ep =  1.9951127829588295

# %%
#let's make Hi-C and do the visualization with Blender!!!
#Yeah~
